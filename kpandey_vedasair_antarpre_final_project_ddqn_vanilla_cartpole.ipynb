# %% [markdown]
# #DDQN Vanilla Cart Pole Environment

# %%
# !pip install gymnasium
# !pip3 install gymnasium[classic_control]

import gymnasium as gym
import torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gymnasium[classic_control]
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (1.22.4)
# Collecting jax-jumpy>=1.0.0
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (4.5.0)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting pygame==2.1.3
#   Downloading pygame-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 15.1 MB/s eta 0:00:00
# Installing collected packages: farama-notifications, pygame, jax-jumpy, gymnasium
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.3.0
#     Uninstalling pygame-2.3.0:
#       Successfully uninstalled pygame-2.3.0
# Successfully installed farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 pygame-2.1.3

# %%
env = gym.make('CartPole-v1')

obs, info = env.reset()

obs_space = env.observation_space.shape[0]
action_space = env.action_space.n

obs, info, obs_space, action_space
# Out:
# (array([ 0.03794919,  0.01555944, -0.02875545,  0.03454918], dtype=float32),
#  {},
#  4,
#  2)

# %%
class DDQNnn(torch.nn.Module):
    def __init__(self) -> None:
        super().__init__()
        self.linear_relu_stack = torch.nn.Sequential(
            torch.nn.Linear(obs_space, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, action_space)
        )
    def forward(self, x):
        return self.linear_relu_stack(x)

nn_first = DDQNnn()
nn_second = DDQNnn()
dict_load = nn_first.state_dict()
nn_second.load_state_dict(dict_load)

nn_first, nn_second
# Out:
# (DDQNnn(
#    (linear_relu_stack): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#      (4): Linear(in_features=256, out_features=2, bias=True)
#    )
#  ),
#  DDQNnn(
#    (linear_relu_stack): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#      (4): Linear(in_features=256, out_features=2, bias=True)
#    )
#  ))

# %%
import random
import numpy as np

from collections import deque
buffer_memory = deque(maxlen = 10000)

def policy_cal(obs):
  random_val = random.random()
  epsilon_val = epsilon_cal()
  if random_val > epsilon_val:
    action_type = 'greedy'
    obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
    action_val = nn_first(obs_tensor).detach().numpy()
    action_val = np.argmax(action_val)
    return action_val, action_type
  else:
    action_type = 'random'
    action_val = env.action_space.sample()
    return action_val, action_type

def policy_learnt(obs):
  action_type = 'greedy'
  obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
  action_val = nn_first(obs_tensor).detach().numpy()
  action_val = np.argmax(action_val)
  return action_val, action_type

import math
epsilon_steps = 0
def epsilon_cal():
  diff_val = 1.0 - 0.05
  global epsilon_steps
  exp_val = math.exp(-1.0 * epsilon_steps / 1000)
  epsilon_steps += 1
  epsilon_val = 0.05 + diff_val * exp_val
  return epsilon_val

optimizer_param = nn_first.parameters()
optimizer = torch.optim.AdamW(optimizer_param, lr=1e-4, amsgrad=True)

# %%
def experience_cal():
  if len(buffer_memory) < 128:
    return
  
  buffer_batch = random.sample(buffer_memory, 128)
  batch_obs1, batch_obs2 = [], []
  batch_reward, batch_action = [], []
  batch_completed = []

  for val in buffer_batch:
    obs1_val, obs2_val, reward_val, action_val, completed_val = val
    batch_completed.append(completed_val)
    batch_obs1.append(obs1_val)
    batch_obs2.append(obs2_val)
    batch_action.append([action_val])
    batch_reward.append(reward_val)    
  
  batch_obs2_nf = []
  for i in range(len(batch_completed)):
    if batch_completed[i]:
      batch_obs2_nf.append(batch_obs2[i])
  
  batch_completed = torch.tensor(batch_completed, dtype=torch.bool) # 128
  batch_obs1 = torch.tensor(batch_obs1) # 128
  batch_obs2 = torch.tensor(batch_obs2) # 128
  batch_obs2_nf = torch.tensor(batch_obs2_nf) # < 128
  batch_action = torch.tensor(batch_action, dtype=torch.int64) # 128
  batch_reward = torch.tensor(batch_reward) # 128
  
  obs1_qval = nn_first(batch_obs1).gather(1, batch_action)
  obs2_qval = nn_second(batch_obs1).gather(1, batch_action)

  batch_obs2_val = torch.zeros(128)
  with torch.set_grad_enabled(False):
    max_val_list = nn_second(batch_obs2_nf).detach()
    max_val = max_val_list.max(1)[0]
    batch_obs2_val[batch_completed] = max_val

  discounted_reward = 0.99 * batch_obs2_val
  obs2_qval = batch_reward + discounted_reward
  
  loss_function = torch.nn.MSELoss()
  criterion = loss_function
  loss_param1 = obs1_qval
  loss_param2 = obs2_qval[:, None]
  loss = criterion(loss_param1, loss_param2)

  optimizer.zero_grad()
  loss.backward()
  
  grad_max_val = 100
  grad_model_param = nn_first.parameters()
  torch.nn.utils.clip_grad_value_(grad_model_param, grad_max_val)
  
  optimizer.step()

  update_cf1 = 0.005
  update_cf2 = 1 - 0.005
  nn_first_dict = nn_first.state_dict()
  nn_second_dict = nn_second.state_dict()
  for dict_key in nn_first.state_dict():
    nn_first_update = update_cf1 * nn_first_dict[dict_key]
    nn_second_update = update_cf2 * nn_second_dict[dict_key]
    update_val = nn_first_update + nn_second_update
    nn_second_dict[dict_key] = update_val
  nn_second.load_state_dict(nn_second_dict)

# %%
rewards = []
for episode in range(500):
  obs1_val, info_val = env.reset()
  completed, term_val, trunc_val = False, False, False
  score, greedy_count, random_count = 0, 0, 0

  while not completed:
    action_val, action_type = policy_cal(obs1_val)
    if action_type == 'greedy':
      greedy_count += 1
    else:
      random_count += 1
  
    obs2_val, reward_val, term_val, trunc_val, info_val = env.step(action_val)
    score += reward_val

    completed = term_val or trunc_val
    completed_val = not completed

    experience = (obs1_val, obs2_val, reward_val, action_val, completed_val)
    buffer_memory.append(experience)
    obs1_val = obs2_val

    experience_cal()

    if completed:
      print(f'Episode: {episode}, Score: {score}, Random: {random_count}, Greedy: {greedy_count}')
      rewards.append(score)
      break
# Out:
# Episode: 0, Score: 40.0, Random: 33, Greedy: 7
# Episode: 1, Score: 12.0, Random: 10, Greedy: 2
# Episode: 2, Score: 30.0, Random: 24, Greedy: 6
# Episode: 3, Score: 13.0, Random: 8, Greedy: 5
# Episode: 4, Score: 10.0, Random: 5, Greedy: 5
# Episode: 5, Score: 16.0, Random: 15, Greedy: 1
# Episode: 6, Score: 21.0, Random: 17, Greedy: 4
# Episode: 7, Score: 17.0, Random: 10, Greedy: 7
# Episode: 8, Score: 12.0, Random: 7, Greedy: 5
# Episode: 9, Score: 11.0, Random: 7, Greedy: 4
# Episode: 10, Score: 13.0, Random: 9, Greedy: 4
# Episode: 11, Score: 13.0, Random: 8, Greedy: 5
# Episode: 12, Score: 25.0, Random: 20, Greedy: 5
# Episode: 13, Score: 14.0, Random: 11, Greedy: 3
# Episode: 14, Score: 14.0, Random: 9, Greedy: 5
# Episode: 15, Score: 12.0, Random: 9, Greedy: 3
# Episode: 16, Score: 10.0, Random: 4, Greedy: 6
# Episode: 17, Score: 9.0, Random: 8, Greedy: 1
# Episode: 18, Score: 19.0, Random: 14, Greedy: 5
# Episode: 19, Score: 16.0, Random: 9, Greedy: 7
# Episode: 20, Score: 16.0, Random: 11, Greedy: 5
# Episode: 21, Score: 15.0, Random: 10, Greedy: 5
# Episode: 22, Score: 13.0, Random: 7, Greedy: 6
# Episode: 23, Score: 14.0, Random: 7, Greedy: 7
# Episode: 24, Score: 14.0, Random: 10, Greedy: 4
# Episode: 25, Score: 17.0, Random: 12, Greedy: 5
# Episode: 26, Score: 10.0, Random: 7, Greedy: 3
# Episode: 27, Score: 11.0, Random: 5, Greedy: 6
# Episode: 28, Score: 15.0, Random: 5, Greedy: 10
# Episode: 29, Score: 13.0, Random: 10, Greedy: 3
# Episode: 30, Score: 14.0, Random: 5, Greedy: 9
# Episode: 31, Score: 54.0, Random: 35, Greedy: 19
# Episode: 32, Score: 12.0, Random: 6, Greedy: 6
# Episode: 33, Score: 79.0, Random: 36, Greedy: 43
# Episode: 34, Score: 35.0, Random: 15, Greedy: 20
# Episode: 35, Score: 56.0, Random: 21, Greedy: 35
# Episode: 36, Score: 47.0, Random: 17, Greedy: 30
# Episode: 37, Score: 30.0, Random: 14, Greedy: 16
# Episode: 38, Score: 66.0, Random: 28, Greedy: 38
# Episode: 39, Score: 42.0, Random: 16, Greedy: 26
# Episode: 40, Score: 33.0, Random: 15, Greedy: 18
# Episode: 41, Score: 118.0, Random: 47, Greedy: 71
# Episode: 42, Score: 24.0, Random: 6, Greedy: 18
# Episode: 43, Score: 48.0, Random: 11, Greedy: 37
# Episode: 44, Score: 76.0, Random: 22, Greedy: 54
# Episode: 45, Score: 140.0, Random: 45, Greedy: 95
# Episode: 46, Score: 190.0, Random: 40, Greedy: 150
# Episode: 47, Score: 192.0, Random: 29, Greedy: 163
# Episode: 48, Score: 187.0, Random: 43, Greedy: 144
# Episode: 49, Score: 183.0, Random: 25, Greedy: 158
# Episode: 50, Score: 154.0, Random: 20, Greedy: 134
# Episode: 51, Score: 344.0, Random: 41, Greedy: 303
# Episode: 52, Score: 342.0, Random: 39, Greedy: 303
# Episode: 53, Score: 222.0, Random: 22, Greedy: 200
# Episode: 54, Score: 239.0, Random: 20, Greedy: 219
# Episode: 55, Score: 282.0, Random: 23, Greedy: 259
# Episode: 56, Score: 253.0, Random: 23, Greedy: 230
# Episode: 57, Score: 279.0, Random: 18, Greedy: 261
# Episode: 58, Score: 242.0, Random: 17, Greedy: 225
# Episode: 59, Score: 245.0, Random: 10, Greedy: 235
# Episode: 60, Score: 289.0, Random: 15, Greedy: 274
# Episode: 61, Score: 198.0, Random: 6, Greedy: 192
# Episode: 62, Score: 257.0, Random: 19, Greedy: 238
# Episode: 63, Score: 195.0, Random: 9, Greedy: 186
# Episode: 64, Score: 233.0, Random: 10, Greedy: 223
# Episode: 65, Score: 253.0, Random: 12, Greedy: 241
# Episode: 66, Score: 209.0, Random: 12, Greedy: 197
# Episode: 67, Score: 223.0, Random: 16, Greedy: 207
# Episode: 68, Score: 229.0, Random: 7, Greedy: 222
# Episode: 69, Score: 301.0, Random: 15, Greedy: 286
# Episode: 70, Score: 281.0, Random: 10, Greedy: 271
# Episode: 71, Score: 194.0, Random: 14, Greedy: 180
# Episode: 72, Score: 272.0, Random: 17, Greedy: 255
# Episode: 73, Score: 205.0, Random: 13, Greedy: 192
# Episode: 74, Score: 183.0, Random: 12, Greedy: 171
# Episode: 75, Score: 202.0, Random: 6, Greedy: 196
# Episode: 76, Score: 215.0, Random: 18, Greedy: 197
# Episode: 77, Score: 256.0, Random: 8, Greedy: 248
# Episode: 78, Score: 209.0, Random: 13, Greedy: 196
# Episode: 79, Score: 211.0, Random: 10, Greedy: 201
# Episode: 80, Score: 199.0, Random: 13, Greedy: 186
# Episode: 81, Score: 225.0, Random: 9, Greedy: 216
# Episode: 82, Score: 211.0, Random: 8, Greedy: 203
# Episode: 83, Score: 251.0, Random: 13, Greedy: 238
# Episode: 84, Score: 257.0, Random: 10, Greedy: 247
# Episode: 85, Score: 277.0, Random: 16, Greedy: 261
# Episode: 86, Score: 240.0, Random: 20, Greedy: 220
# Episode: 87, Score: 271.0, Random: 19, Greedy: 252
# Episode: 88, Score: 202.0, Random: 12, Greedy: 190
# Episode: 89, Score: 208.0, Random: 11, Greedy: 197
# Episode: 90, Score: 236.0, Random: 9, Greedy: 227
# Episode: 91, Score: 231.0, Random: 8, Greedy: 223
# Episode: 92, Score: 273.0, Random: 15, Greedy: 258
# Episode: 93, Score: 243.0, Random: 10, Greedy: 233
# Episode: 94, Score: 404.0, Random: 19, Greedy: 385
# Episode: 95, Score: 215.0, Random: 9, Greedy: 206
# Episode: 96, Score: 220.0, Random: 10, Greedy: 210
# Episode: 97, Score: 248.0, Random: 13, Greedy: 235
# Episode: 98, Score: 462.0, Random: 19, Greedy: 443
# Episode: 99, Score: 243.0, Random: 10, Greedy: 233
# Episode: 100, Score: 208.0, Random: 10, Greedy: 198
# Episode: 101, Score: 256.0, Random: 7, Greedy: 249
# Episode: 102, Score: 287.0, Random: 16, Greedy: 271
# Episode: 103, Score: 231.0, Random: 11, Greedy: 220
# Episode: 104, Score: 264.0, Random: 16, Greedy: 248
# Episode: 105, Score: 196.0, Random: 8, Greedy: 188
# Episode: 106, Score: 195.0, Random: 14, Greedy: 181
# Episode: 107, Score: 210.0, Random: 11, Greedy: 199
# Episode: 108, Score: 251.0, Random: 11, Greedy: 240
# Episode: 109, Score: 253.0, Random: 17, Greedy: 236
# Episode: 110, Score: 207.0, Random: 8, Greedy: 199
# Episode: 111, Score: 268.0, Random: 14, Greedy: 254
# Episode: 112, Score: 227.0, Random: 12, Greedy: 215
# Episode: 113, Score: 207.0, Random: 12, Greedy: 195
# Episode: 114, Score: 199.0, Random: 8, Greedy: 191
# Episode: 115, Score: 206.0, Random: 10, Greedy: 196
# Episode: 116, Score: 208.0, Random: 14, Greedy: 194
# Episode: 117, Score: 195.0, Random: 11, Greedy: 184
# Episode: 118, Score: 351.0, Random: 17, Greedy: 334
# Episode: 119, Score: 214.0, Random: 9, Greedy: 205
# Episode: 120, Score: 219.0, Random: 11, Greedy: 208
# Episode: 121, Score: 222.0, Random: 10, Greedy: 212
# Episode: 122, Score: 200.0, Random: 8, Greedy: 192
# Episode: 123, Score: 210.0, Random: 8, Greedy: 202
# Episode: 124, Score: 280.0, Random: 15, Greedy: 265
# Episode: 125, Score: 238.0, Random: 12, Greedy: 226
# Episode: 126, Score: 232.0, Random: 7, Greedy: 225
# Episode: 127, Score: 283.0, Random: 16, Greedy: 267
# Episode: 128, Score: 218.0, Random: 8, Greedy: 210
# Episode: 129, Score: 218.0, Random: 11, Greedy: 207
# Episode: 130, Score: 223.0, Random: 11, Greedy: 212
# Episode: 131, Score: 255.0, Random: 11, Greedy: 244
# Episode: 132, Score: 266.0, Random: 6, Greedy: 260
# Episode: 133, Score: 265.0, Random: 7, Greedy: 258
# Episode: 134, Score: 337.0, Random: 19, Greedy: 318
# Episode: 135, Score: 199.0, Random: 16, Greedy: 183
# Episode: 136, Score: 256.0, Random: 14, Greedy: 242
# Episode: 137, Score: 253.0, Random: 9, Greedy: 244
# Episode: 138, Score: 219.0, Random: 5, Greedy: 214
# Episode: 139, Score: 218.0, Random: 10, Greedy: 208
# Episode: 140, Score: 215.0, Random: 12, Greedy: 203
# Episode: 141, Score: 221.0, Random: 12, Greedy: 209
# Episode: 142, Score: 219.0, Random: 7, Greedy: 212
# Episode: 143, Score: 194.0, Random: 14, Greedy: 180
# Episode: 144, Score: 312.0, Random: 17, Greedy: 295
# Episode: 145, Score: 207.0, Random: 9, Greedy: 198
# Episode: 146, Score: 242.0, Random: 9, Greedy: 233
# Episode: 147, Score: 250.0, Random: 14, Greedy: 236
# Episode: 148, Score: 323.0, Random: 17, Greedy: 306
# Episode: 149, Score: 264.0, Random: 9, Greedy: 255
# Episode: 150, Score: 213.0, Random: 8, Greedy: 205
# Episode: 151, Score: 222.0, Random: 13, Greedy: 209
# Episode: 152, Score: 229.0, Random: 19, Greedy: 210
# Episode: 153, Score: 251.0, Random: 15, Greedy: 236
# Episode: 154, Score: 215.0, Random: 8, Greedy: 207
# Episode: 155, Score: 279.0, Random: 18, Greedy: 261
# Episode: 156, Score: 247.0, Random: 8, Greedy: 239
# Episode: 157, Score: 317.0, Random: 11, Greedy: 306
# Episode: 158, Score: 269.0, Random: 15, Greedy: 254
# Episode: 159, Score: 332.0, Random: 19, Greedy: 313
# Episode: 160, Score: 329.0, Random: 14, Greedy: 315
# Episode: 161, Score: 235.0, Random: 11, Greedy: 224
# Episode: 162, Score: 204.0, Random: 15, Greedy: 189
# Episode: 163, Score: 268.0, Random: 16, Greedy: 252
# Episode: 164, Score: 269.0, Random: 6, Greedy: 263
# Episode: 165, Score: 289.0, Random: 17, Greedy: 272
# Episode: 166, Score: 197.0, Random: 8, Greedy: 189
# Episode: 167, Score: 337.0, Random: 19, Greedy: 318
# Episode: 168, Score: 340.0, Random: 13, Greedy: 327
# Episode: 169, Score: 210.0, Random: 14, Greedy: 196
# Episode: 170, Score: 214.0, Random: 14, Greedy: 200
# Episode: 171, Score: 333.0, Random: 17, Greedy: 316
# Episode: 172, Score: 242.0, Random: 12, Greedy: 230
# Episode: 173, Score: 264.0, Random: 15, Greedy: 249
# Episode: 174, Score: 320.0, Random: 17, Greedy: 303
# Episode: 175, Score: 242.0, Random: 8, Greedy: 234
# Episode: 176, Score: 405.0, Random: 12, Greedy: 393
# Episode: 177, Score: 211.0, Random: 6, Greedy: 205
# Episode: 178, Score: 218.0, Random: 13, Greedy: 205
# Episode: 179, Score: 202.0, Random: 14, Greedy: 188
# Episode: 180, Score: 203.0, Random: 11, Greedy: 192
# Episode: 181, Score: 234.0, Random: 10, Greedy: 224
# Episode: 182, Score: 194.0, Random: 13, Greedy: 181
# Episode: 183, Score: 240.0, Random: 5, Greedy: 235
# Episode: 184, Score: 224.0, Random: 7, Greedy: 217
# Episode: 185, Score: 198.0, Random: 13, Greedy: 185
# Episode: 186, Score: 259.0, Random: 9, Greedy: 250
# Episode: 187, Score: 283.0, Random: 15, Greedy: 268
# Episode: 188, Score: 213.0, Random: 11, Greedy: 202
# Episode: 189, Score: 343.0, Random: 14, Greedy: 329
# Episode: 190, Score: 171.0, Random: 7, Greedy: 164
# Episode: 191, Score: 165.0, Random: 11, Greedy: 154
# Episode: 192, Score: 223.0, Random: 14, Greedy: 209
# Episode: 193, Score: 275.0, Random: 15, Greedy: 260
# Episode: 194, Score: 277.0, Random: 16, Greedy: 261
# Episode: 195, Score: 254.0, Random: 12, Greedy: 242
# Episode: 196, Score: 220.0, Random: 16, Greedy: 204
# Episode: 197, Score: 435.0, Random: 28, Greedy: 407
# Episode: 198, Score: 272.0, Random: 13, Greedy: 259
# Episode: 199, Score: 362.0, Random: 15, Greedy: 347
# Episode: 200, Score: 280.0, Random: 17, Greedy: 263
# Episode: 201, Score: 258.0, Random: 14, Greedy: 244
# Episode: 202, Score: 380.0, Random: 16, Greedy: 364
# Episode: 203, Score: 305.0, Random: 17, Greedy: 288
# Episode: 204, Score: 321.0, Random: 16, Greedy: 305
# Episode: 205, Score: 286.0, Random: 11, Greedy: 275
# Episode: 206, Score: 234.0, Random: 12, Greedy: 222
# Episode: 207, Score: 235.0, Random: 9, Greedy: 226
# Episode: 208, Score: 230.0, Random: 15, Greedy: 215
# Episode: 209, Score: 327.0, Random: 19, Greedy: 308
# Episode: 210, Score: 244.0, Random: 12, Greedy: 232
# Episode: 211, Score: 187.0, Random: 9, Greedy: 178
# Episode: 212, Score: 328.0, Random: 16, Greedy: 312
# Episode: 213, Score: 219.0, Random: 11, Greedy: 208
# Episode: 214, Score: 218.0, Random: 8, Greedy: 210
# Episode: 215, Score: 247.0, Random: 10, Greedy: 237
# Episode: 216, Score: 321.0, Random: 12, Greedy: 309
# Episode: 217, Score: 260.0, Random: 12, Greedy: 248
# Episode: 218, Score: 275.0, Random: 15, Greedy: 260
# Episode: 219, Score: 202.0, Random: 20, Greedy: 182
# Episode: 220, Score: 227.0, Random: 9, Greedy: 218
# Episode: 221, Score: 307.0, Random: 15, Greedy: 292
# Episode: 222, Score: 233.0, Random: 15, Greedy: 218
# Episode: 223, Score: 299.0, Random: 14, Greedy: 285
# Episode: 224, Score: 199.0, Random: 18, Greedy: 181
# Episode: 225, Score: 234.0, Random: 14, Greedy: 220
# Episode: 226, Score: 264.0, Random: 12, Greedy: 252
# Episode: 227, Score: 500.0, Random: 29, Greedy: 471
# Episode: 228, Score: 432.0, Random: 34, Greedy: 398
# Episode: 229, Score: 232.0, Random: 12, Greedy: 220
# Episode: 230, Score: 316.0, Random: 10, Greedy: 306
# Episode: 231, Score: 288.0, Random: 15, Greedy: 273
# Episode: 232, Score: 221.0, Random: 10, Greedy: 211
# Episode: 233, Score: 209.0, Random: 8, Greedy: 201
# Episode: 234, Score: 427.0, Random: 24, Greedy: 403
# Episode: 235, Score: 265.0, Random: 12, Greedy: 253
# Episode: 236, Score: 326.0, Random: 30, Greedy: 296
# Episode: 237, Score: 305.0, Random: 10, Greedy: 295
# Episode: 238, Score: 356.0, Random: 25, Greedy: 331
# Episode: 239, Score: 491.0, Random: 13, Greedy: 478
# Episode: 240, Score: 224.0, Random: 7, Greedy: 217
# Episode: 241, Score: 467.0, Random: 29, Greedy: 438
# Episode: 242, Score: 241.0, Random: 14, Greedy: 227
# Episode: 243, Score: 244.0, Random: 14, Greedy: 230
# Episode: 244, Score: 344.0, Random: 22, Greedy: 322
# Episode: 245, Score: 229.0, Random: 12, Greedy: 217
# Episode: 246, Score: 500.0, Random: 18, Greedy: 482
# Episode: 247, Score: 233.0, Random: 18, Greedy: 215
# Episode: 248, Score: 354.0, Random: 14, Greedy: 340
# Episode: 249, Score: 262.0, Random: 12, Greedy: 250
# Episode: 250, Score: 325.0, Random: 13, Greedy: 312
# Episode: 251, Score: 328.0, Random: 18, Greedy: 310
# Episode: 252, Score: 500.0, Random: 28, Greedy: 472
# Episode: 253, Score: 294.0, Random: 14, Greedy: 280
# Episode: 254, Score: 366.0, Random: 16, Greedy: 350
# Episode: 255, Score: 277.0, Random: 18, Greedy: 259
# Episode: 256, Score: 273.0, Random: 6, Greedy: 267
# Episode: 257, Score: 339.0, Random: 21, Greedy: 318
# Episode: 258, Score: 318.0, Random: 18, Greedy: 300
# Episode: 259, Score: 232.0, Random: 12, Greedy: 220
# Episode: 260, Score: 399.0, Random: 16, Greedy: 383
# Episode: 261, Score: 500.0, Random: 26, Greedy: 474
# Episode: 262, Score: 216.0, Random: 10, Greedy: 206
# Episode: 263, Score: 408.0, Random: 18, Greedy: 390
# Episode: 264, Score: 251.0, Random: 8, Greedy: 243
# Episode: 265, Score: 393.0, Random: 17, Greedy: 376
# Episode: 266, Score: 409.0, Random: 14, Greedy: 395
# Episode: 267, Score: 392.0, Random: 14, Greedy: 378
# Episode: 268, Score: 280.0, Random: 17, Greedy: 263
# Episode: 269, Score: 292.0, Random: 14, Greedy: 278
# Episode: 270, Score: 439.0, Random: 15, Greedy: 424
# Episode: 271, Score: 500.0, Random: 31, Greedy: 469
# Episode: 272, Score: 284.0, Random: 13, Greedy: 271
# Episode: 273, Score: 303.0, Random: 13, Greedy: 290
# Episode: 274, Score: 334.0, Random: 23, Greedy: 311
# Episode: 275, Score: 282.0, Random: 14, Greedy: 268
# Episode: 276, Score: 500.0, Random: 26, Greedy: 474
# Episode: 277, Score: 297.0, Random: 13, Greedy: 284
# Episode: 278, Score: 362.0, Random: 15, Greedy: 347
# Episode: 279, Score: 242.0, Random: 13, Greedy: 229
# Episode: 280, Score: 324.0, Random: 13, Greedy: 311
# Episode: 281, Score: 285.0, Random: 17, Greedy: 268
# Episode: 282, Score: 299.0, Random: 13, Greedy: 286
# Episode: 283, Score: 489.0, Random: 29, Greedy: 460
# Episode: 284, Score: 371.0, Random: 20, Greedy: 351
# Episode: 285, Score: 221.0, Random: 15, Greedy: 206
# Episode: 286, Score: 235.0, Random: 14, Greedy: 221
# Episode: 287, Score: 276.0, Random: 19, Greedy: 257
# Episode: 288, Score: 468.0, Random: 29, Greedy: 439
# Episode: 289, Score: 346.0, Random: 15, Greedy: 331
# Episode: 290, Score: 247.0, Random: 8, Greedy: 239
# Episode: 291, Score: 214.0, Random: 13, Greedy: 201
# Episode: 292, Score: 489.0, Random: 30, Greedy: 459
# Episode: 293, Score: 266.0, Random: 13, Greedy: 253
# Episode: 294, Score: 391.0, Random: 16, Greedy: 375
# Episode: 295, Score: 347.0, Random: 18, Greedy: 329
# Episode: 296, Score: 356.0, Random: 17, Greedy: 339
# Episode: 297, Score: 328.0, Random: 16, Greedy: 312
# Episode: 298, Score: 500.0, Random: 28, Greedy: 472
# Episode: 299, Score: 327.0, Random: 17, Greedy: 310
# Episode: 300, Score: 276.0, Random: 11, Greedy: 265
# Episode: 301, Score: 422.0, Random: 22, Greedy: 400
# Episode: 302, Score: 483.0, Random: 31, Greedy: 452
# Episode: 303, Score: 500.0, Random: 22, Greedy: 478
# Episode: 304, Score: 500.0, Random: 28, Greedy: 472
# Episode: 305, Score: 500.0, Random: 22, Greedy: 478
# Episode: 306, Score: 276.0, Random: 11, Greedy: 265
# Episode: 307, Score: 500.0, Random: 31, Greedy: 469
# Episode: 308, Score: 271.0, Random: 8, Greedy: 263
# Episode: 309, Score: 500.0, Random: 17, Greedy: 483
# Episode: 310, Score: 227.0, Random: 22, Greedy: 205
# Episode: 311, Score: 355.0, Random: 23, Greedy: 332
# Episode: 312, Score: 390.0, Random: 20, Greedy: 370
# Episode: 313, Score: 291.0, Random: 19, Greedy: 272
# Episode: 314, Score: 500.0, Random: 25, Greedy: 475
# Episode: 315, Score: 500.0, Random: 24, Greedy: 476
# Episode: 316, Score: 500.0, Random: 24, Greedy: 476
# Episode: 317, Score: 500.0, Random: 32, Greedy: 468
# Episode: 318, Score: 500.0, Random: 19, Greedy: 481
# Episode: 319, Score: 500.0, Random: 20, Greedy: 480
# Episode: 320, Score: 500.0, Random: 35, Greedy: 465
# Episode: 321, Score: 500.0, Random: 19, Greedy: 481
# Episode: 322, Score: 500.0, Random: 15, Greedy: 485
# Episode: 323, Score: 500.0, Random: 19, Greedy: 481
# Episode: 324, Score: 500.0, Random: 27, Greedy: 473
# Episode: 325, Score: 500.0, Random: 21, Greedy: 479
# Episode: 326, Score: 500.0, Random: 30, Greedy: 470
# Episode: 327, Score: 383.0, Random: 11, Greedy: 372
# Episode: 328, Score: 289.0, Random: 17, Greedy: 272
# Episode: 329, Score: 341.0, Random: 17, Greedy: 324
# Episode: 330, Score: 500.0, Random: 25, Greedy: 475
# Episode: 331, Score: 500.0, Random: 30, Greedy: 470
# Episode: 332, Score: 500.0, Random: 20, Greedy: 480
# Episode: 333, Score: 500.0, Random: 19, Greedy: 481
# Episode: 334, Score: 500.0, Random: 27, Greedy: 473
# Episode: 335, Score: 474.0, Random: 29, Greedy: 445
# Episode: 336, Score: 500.0, Random: 17, Greedy: 483
# Episode: 337, Score: 463.0, Random: 25, Greedy: 438
# Episode: 338, Score: 500.0, Random: 21, Greedy: 479
# Episode: 339, Score: 500.0, Random: 25, Greedy: 475
# Episode: 340, Score: 500.0, Random: 26, Greedy: 474
# Episode: 341, Score: 500.0, Random: 28, Greedy: 472
# Episode: 342, Score: 470.0, Random: 22, Greedy: 448
# Episode: 343, Score: 500.0, Random: 27, Greedy: 473
# Episode: 344, Score: 500.0, Random: 26, Greedy: 474
# Episode: 345, Score: 500.0, Random: 30, Greedy: 470
# Episode: 346, Score: 500.0, Random: 25, Greedy: 475
# Episode: 347, Score: 500.0, Random: 29, Greedy: 471
# Episode: 348, Score: 500.0, Random: 29, Greedy: 471
# Episode: 349, Score: 500.0, Random: 23, Greedy: 477
# Episode: 350, Score: 500.0, Random: 27, Greedy: 473
# Episode: 351, Score: 500.0, Random: 30, Greedy: 470
# Episode: 352, Score: 500.0, Random: 27, Greedy: 473
# Episode: 353, Score: 500.0, Random: 20, Greedy: 480
# Episode: 354, Score: 500.0, Random: 30, Greedy: 470
# Episode: 355, Score: 500.0, Random: 30, Greedy: 470
# Episode: 356, Score: 500.0, Random: 29, Greedy: 471
# Episode: 357, Score: 500.0, Random: 21, Greedy: 479
# Episode: 358, Score: 500.0, Random: 27, Greedy: 473
# Episode: 359, Score: 500.0, Random: 29, Greedy: 471
# Episode: 360, Score: 500.0, Random: 27, Greedy: 473
# Episode: 361, Score: 500.0, Random: 15, Greedy: 485
# Episode: 362, Score: 500.0, Random: 23, Greedy: 477
# Episode: 363, Score: 500.0, Random: 22, Greedy: 478
# Episode: 364, Score: 500.0, Random: 22, Greedy: 478
# Episode: 365, Score: 500.0, Random: 18, Greedy: 482
# Episode: 366, Score: 500.0, Random: 17, Greedy: 483
# Episode: 367, Score: 500.0, Random: 20, Greedy: 480
# Episode: 368, Score: 500.0, Random: 27, Greedy: 473
# Episode: 369, Score: 500.0, Random: 26, Greedy: 474
# Episode: 370, Score: 500.0, Random: 25, Greedy: 475
# Episode: 371, Score: 500.0, Random: 18, Greedy: 482
# Episode: 372, Score: 500.0, Random: 24, Greedy: 476
# Episode: 373, Score: 500.0, Random: 28, Greedy: 472
# Episode: 374, Score: 500.0, Random: 32, Greedy: 468
# Episode: 375, Score: 500.0, Random: 29, Greedy: 471
# Episode: 376, Score: 500.0, Random: 23, Greedy: 477
# Episode: 377, Score: 500.0, Random: 17, Greedy: 483
# Episode: 378, Score: 500.0, Random: 31, Greedy: 469
# Episode: 379, Score: 500.0, Random: 23, Greedy: 477
# Episode: 380, Score: 500.0, Random: 27, Greedy: 473
# Episode: 381, Score: 500.0, Random: 27, Greedy: 473
# Episode: 382, Score: 500.0, Random: 20, Greedy: 480
# Episode: 383, Score: 500.0, Random: 30, Greedy: 470
# Episode: 384, Score: 500.0, Random: 26, Greedy: 474
# Episode: 385, Score: 500.0, Random: 26, Greedy: 474
# Episode: 386, Score: 500.0, Random: 28, Greedy: 472
# Episode: 387, Score: 500.0, Random: 22, Greedy: 478
# Episode: 388, Score: 500.0, Random: 26, Greedy: 474
# Episode: 389, Score: 500.0, Random: 23, Greedy: 477
# Episode: 390, Score: 500.0, Random: 20, Greedy: 480
# Episode: 391, Score: 500.0, Random: 21, Greedy: 479
# Episode: 392, Score: 500.0, Random: 30, Greedy: 470
# Episode: 393, Score: 500.0, Random: 18, Greedy: 482
# Episode: 394, Score: 500.0, Random: 23, Greedy: 477
# Episode: 395, Score: 500.0, Random: 28, Greedy: 472
# Episode: 396, Score: 500.0, Random: 17, Greedy: 483
# Episode: 397, Score: 500.0, Random: 20, Greedy: 480
# Episode: 398, Score: 500.0, Random: 31, Greedy: 469
# Episode: 399, Score: 500.0, Random: 35, Greedy: 465
# Episode: 400, Score: 500.0, Random: 35, Greedy: 465
# Episode: 401, Score: 500.0, Random: 28, Greedy: 472
# Episode: 402, Score: 500.0, Random: 26, Greedy: 474
# Episode: 403, Score: 500.0, Random: 27, Greedy: 473
# Episode: 404, Score: 500.0, Random: 28, Greedy: 472
# Episode: 405, Score: 500.0, Random: 28, Greedy: 472
# Episode: 406, Score: 500.0, Random: 19, Greedy: 481
# Episode: 407, Score: 500.0, Random: 22, Greedy: 478
# Episode: 408, Score: 500.0, Random: 24, Greedy: 476
# Episode: 409, Score: 500.0, Random: 22, Greedy: 478
# Episode: 410, Score: 500.0, Random: 24, Greedy: 476
# Episode: 411, Score: 500.0, Random: 28, Greedy: 472
# Episode: 412, Score: 500.0, Random: 19, Greedy: 481
# Episode: 413, Score: 500.0, Random: 22, Greedy: 478
# Episode: 414, Score: 500.0, Random: 23, Greedy: 477
# Episode: 415, Score: 500.0, Random: 27, Greedy: 473
# Episode: 416, Score: 500.0, Random: 25, Greedy: 475
# Episode: 417, Score: 500.0, Random: 24, Greedy: 476
# Episode: 418, Score: 500.0, Random: 22, Greedy: 478
# Episode: 419, Score: 500.0, Random: 24, Greedy: 476
# Episode: 420, Score: 500.0, Random: 24, Greedy: 476
# Episode: 421, Score: 500.0, Random: 25, Greedy: 475
# Episode: 422, Score: 500.0, Random: 27, Greedy: 473
# Episode: 423, Score: 500.0, Random: 31, Greedy: 469
# Episode: 424, Score: 500.0, Random: 24, Greedy: 476
# Episode: 425, Score: 500.0, Random: 27, Greedy: 473
# Episode: 426, Score: 500.0, Random: 28, Greedy: 472
# Episode: 427, Score: 500.0, Random: 19, Greedy: 481
# Episode: 428, Score: 500.0, Random: 17, Greedy: 483
# Episode: 429, Score: 500.0, Random: 23, Greedy: 477
# Episode: 430, Score: 500.0, Random: 23, Greedy: 477
# Episode: 431, Score: 500.0, Random: 24, Greedy: 476
# Episode: 432, Score: 500.0, Random: 22, Greedy: 478
# Episode: 433, Score: 500.0, Random: 27, Greedy: 473
# Episode: 434, Score: 500.0, Random: 21, Greedy: 479
# Episode: 435, Score: 500.0, Random: 33, Greedy: 467
# Episode: 436, Score: 500.0, Random: 18, Greedy: 482
# Episode: 437, Score: 500.0, Random: 32, Greedy: 468
# Episode: 438, Score: 500.0, Random: 27, Greedy: 473
# Episode: 439, Score: 500.0, Random: 16, Greedy: 484
# Episode: 440, Score: 500.0, Random: 27, Greedy: 473
# Episode: 441, Score: 500.0, Random: 24, Greedy: 476
# Episode: 442, Score: 500.0, Random: 30, Greedy: 470
# Episode: 443, Score: 500.0, Random: 29, Greedy: 471
# Episode: 444, Score: 500.0, Random: 24, Greedy: 476
# Episode: 445, Score: 500.0, Random: 30, Greedy: 470
# Episode: 446, Score: 500.0, Random: 26, Greedy: 474
# Episode: 447, Score: 500.0, Random: 23, Greedy: 477
# Episode: 448, Score: 500.0, Random: 19, Greedy: 481
# Episode: 449, Score: 500.0, Random: 25, Greedy: 475
# Episode: 450, Score: 500.0, Random: 24, Greedy: 476
# Episode: 451, Score: 500.0, Random: 21, Greedy: 479
# Episode: 452, Score: 500.0, Random: 16, Greedy: 484
# Episode: 453, Score: 500.0, Random: 21, Greedy: 479
# Episode: 454, Score: 500.0, Random: 24, Greedy: 476
# Episode: 455, Score: 500.0, Random: 28, Greedy: 472
# Episode: 456, Score: 500.0, Random: 24, Greedy: 476
# Episode: 457, Score: 500.0, Random: 30, Greedy: 470
# Episode: 458, Score: 500.0, Random: 24, Greedy: 476
# Episode: 459, Score: 500.0, Random: 25, Greedy: 475
# Episode: 460, Score: 500.0, Random: 23, Greedy: 477
# Episode: 461, Score: 500.0, Random: 33, Greedy: 467
# Episode: 462, Score: 500.0, Random: 30, Greedy: 470
# Episode: 463, Score: 500.0, Random: 16, Greedy: 484
# Episode: 464, Score: 500.0, Random: 20, Greedy: 480
# Episode: 465, Score: 500.0, Random: 31, Greedy: 469
# Episode: 466, Score: 500.0, Random: 20, Greedy: 480
# Episode: 467, Score: 500.0, Random: 25, Greedy: 475
# Episode: 468, Score: 500.0, Random: 19, Greedy: 481
# Episode: 469, Score: 500.0, Random: 25, Greedy: 475
# Episode: 470, Score: 500.0, Random: 27, Greedy: 473
# Episode: 471, Score: 500.0, Random: 35, Greedy: 465
# Episode: 472, Score: 500.0, Random: 32, Greedy: 468
# Episode: 473, Score: 500.0, Random: 25, Greedy: 475
# Episode: 474, Score: 500.0, Random: 22, Greedy: 478
# Episode: 475, Score: 500.0, Random: 23, Greedy: 477
# Episode: 476, Score: 500.0, Random: 26, Greedy: 474
# Episode: 477, Score: 500.0, Random: 24, Greedy: 476
# Episode: 478, Score: 500.0, Random: 28, Greedy: 472
# Episode: 479, Score: 500.0, Random: 17, Greedy: 483
# Episode: 480, Score: 500.0, Random: 17, Greedy: 483
# Episode: 481, Score: 500.0, Random: 17, Greedy: 483
# Episode: 482, Score: 500.0, Random: 31, Greedy: 469
# Episode: 483, Score: 500.0, Random: 23, Greedy: 477
# Episode: 484, Score: 500.0, Random: 24, Greedy: 476
# Episode: 485, Score: 500.0, Random: 23, Greedy: 477
# Episode: 486, Score: 500.0, Random: 25, Greedy: 475
# Episode: 487, Score: 500.0, Random: 24, Greedy: 476
# Episode: 488, Score: 500.0, Random: 29, Greedy: 471
# Episode: 489, Score: 500.0, Random: 21, Greedy: 479
# Episode: 490, Score: 500.0, Random: 33, Greedy: 467
# Episode: 491, Score: 500.0, Random: 31, Greedy: 469
# Episode: 492, Score: 500.0, Random: 22, Greedy: 478
# Episode: 493, Score: 500.0, Random: 27, Greedy: 473
# Episode: 494, Score: 500.0, Random: 31, Greedy: 469
# Episode: 495, Score: 500.0, Random: 31, Greedy: 469
# Episode: 496, Score: 500.0, Random: 25, Greedy: 475
# Episode: 497, Score: 500.0, Random: 24, Greedy: 476
# Episode: 498, Score: 500.0, Random: 23, Greedy: 477
# Episode: 499, Score: 500.0, Random: 23, Greedy: 477

# %%
rewards_test = []
for episode in range(10):
  obs1_val, info_val = env.reset()
  completed, term_val, trunc_val = False, False, False
  score, greedy_count, random_count = 0, 0, 0

  while not completed:
    action_val, action_type = policy_learnt(obs1_val)
    if action_type == 'greedy':
      greedy_count += 1
    else:
      random_count += 1
  
    obs2_val, reward_val, term_val, trunc_val, info_val = env.step(action_val)
    score += reward_val

    completed = term_val or trunc_val

    obs1_val = obs2_val

    if completed:
      print(f'Episode: {episode}, Score: {score}, Random: {random_count}, Greedy: {greedy_count}')
      rewards_test.append(score)
      break
# Out:
# Episode: 0, Score: 500.0, Random: 0, Greedy: 500
# Episode: 1, Score: 500.0, Random: 0, Greedy: 500
# Episode: 2, Score: 500.0, Random: 0, Greedy: 500
# Episode: 3, Score: 500.0, Random: 0, Greedy: 500
# Episode: 4, Score: 500.0, Random: 0, Greedy: 500
# Episode: 5, Score: 500.0, Random: 0, Greedy: 500
# Episode: 6, Score: 500.0, Random: 0, Greedy: 500
# Episode: 7, Score: 500.0, Random: 0, Greedy: 500
# Episode: 8, Score: 500.0, Random: 0, Greedy: 500
# Episode: 9, Score: 500.0, Random: 0, Greedy: 500

# %%
torch.save(nn_first.state_dict(), 'ddqn_vanilla_cartpole_weights.pth')

# %%
import matplotlib.pyplot as plt

def plot_reward(reward):
  plt.plot(reward, label='Reward')
  plt.xlabel('Episode')
  plt.ylabel('Reward Value')
  plt.title('Rewards Per Episode')
  plt.grid()
  plt.legend()
  plt.show()

plot_reward(rewards)
plot_reward(rewards_test)

# %%
import pickle
with open('ddqn_vanilla_cartpole_train.pkl', 'wb') as file:
  pickle.dump(rewards, file)

with open('ddqn_vanilla_cartpole_test.pkl', 'wb') as file:
  pickle.dump(rewards_test, file)
