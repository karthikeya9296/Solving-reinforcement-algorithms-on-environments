# %%
! pip install gym
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)

# %%
import torch
import torch.nn as nn

import torch.nn.functional as F
import torch.multiprocessing as mp

import gym
import os
from torch import nn
import torch
import numpy as np
import pickle

# %%
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.multiprocessing as mp
import matplotlib.pyplot as plt
from gym import spaces

# %%
# Wind noise function
def wind_noise(action):
  wind_direction = np.random.randint(0, 3)
  double_action = False
  
  if wind_direction == 0:  
    wind_action = action

  elif wind_direction == 1 and action == 0:
    wind_action = 0  
    double_action = True


  elif wind_direction == 2 and action == 1:
    wind_action = 1  
    double_action = True
    
  else:
    wind_action = action

  return double_action, wind_action

def modified_env_step(environment, action):
    double_action, wind_action = wind_noise(action)

    if not double_action:
        observation, reward, terminated, info = environment.step(wind_action)
    else:
        observation, reward1, terminated, info = environment.step(action)
        observation, reward2, terminated, info = environment.step(wind_action)
        reward = reward1 + reward2

    return observation, reward, terminated, info

environment = gym.make('CartPole-v1')
observation = environment.reset()

action = environment.action_space.sample()

observation, reward, terminated, info = modified_env_step(environment, action)

print(observation, reward, terminated, info)
# Out:
# [-0.04272718  0.21924527 -0.04693168 -0.34428436] 1.0 False {}
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
class CartPoleWind(gym.Env):
    def __init__(self):
        self.env = gym.make('CartPole-v1')
        self.action_space = self.env.action_space
        self.observation_space = self.env.observation_space

    def step(self, action):
        return modified_env_step(self.env, action)

    def reset(self):
        return self.env.reset()

    def render(self, mode='human'):
        return self.env.render(mode)

    def close(self):
        return self.env.close()

# %%
class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(ActorCritic, self).__init__()
        self.actor = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim),
            nn.Softmax(dim=-1)
        )

        self.critic = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self, state):
        action_probs = self.actor(state)
        value = self.critic(state)
        return action_probs, value

def convert_to_tensor(state):
    state = torch.from_numpy(state).float().unsqueeze(0)
    return state

def select_action(actor_critic, state):
    state = convert_to_tensor(state)
    action_probs, _ = actor_critic(state)
    arrange_action_probs = np.arange(len(action_probs[0]))
    action = np.random.choice(arrange_action_probs, p=action_probs.detach().numpy()[0])
    return action

def evaluate_action(actor_critic, state):
    state = convert_to_tensor(state)
    with torch.no_grad():
        value, action_probs = actor_critic(state)
    action = torch.argmax(action_probs).item()
    return action

def optimize_model(actor_critic, state, action, reward, next_state, done, optimizer, gamma):
    state = convert_to_tensor(state)
    next_state = convert_to_tensor(next_state)
    reward = torch.tensor([reward], dtype=torch.float32)
    done = torch.tensor([1 - int(done)], dtype=torch.float32)

    _, value = actor_critic(state)
    _, next_value = actor_critic(next_state)

    target = reward + gamma * next_value * done
    td_error = target - value

    action_probs, _ = actor_critic(state)
    log_prob = torch.log(action_probs.squeeze(0)[action])
    actor_loss = -log_prob * td_error.detach()

    critic_loss = td_error.pow(2)

    loss = actor_loss + critic_loss

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()


def train_a3c(env, gamma, lr, max_episodes):

    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n

    actor_critic = ActorCritic(state_dim, action_dim)
    actor_critic.share_memory()
    optimizer = optim.Adam(actor_critic.parameters(), lr=lr)

    num_processes = mp.cpu_count()
    processes = []
    for rank in range(num_processes):
        p = mp.Process(target=run_a3c, args=(rank, actor_critic, env, gamma, lr, max_episodes))
        p.start()
        processes.append(p)
    for p in processes:
        p.join()

    with open('episode_rewards.pkl', 'rb') as f:
        episode_rewards = pickle.load(f)
    with open('avg_rewards.pkl', 'rb') as f:
        avg_reward_list = pickle.load(f)

    plt.plot(episode_rewards, 'g', label='Reward')
    plt.plot(avg_reward_list, 'r', label='Average Reward')
    plt.xlabel('Episode')
    plt.ylabel('Reward Value')
    plt.title('Rewards Per Episode')
    plt.grid()
    plt.legend()
    plt.show()


    # plt.plot(np.arange(len(avg_reward_list)), avg_reward_list)
    # plt.xlabel('Episode')
    # plt.ylabel('Average Reward')
    # plt.title('Average Reward per Episode')
    # plt.show()

    torch.save(actor_critic.state_dict(), 'actor_critic_noise.pt')
    print('Model saved.')

# %%
def run_a3c(rank, actor_critic, env_name, gamma, lr, max_episodes):
    env.seed(rank)
    torch.manual_seed(rank)

    optimizer = optim.Adam(actor_critic.parameters(), lr=lr)

    episode_rewards = []
    avg_reward_list = []
    for episode in range(max_episodes):
        state = env.reset()
        done = False
        total_reward = 0
        while not done:
            action = select_action(actor_critic, state)
            env_list = env.step(action)
            next_state = env_list[0]
            reward = env_list[1]
            done = env_list[2]
            _ = env_list[3]
            total_reward += reward

            optimize_model(actor_critic, state, action, reward, next_state, done, optimizer, gamma)
            state = next_state

        episode_rewards.append(total_reward)
      
        avg_reward_list.append(sum(episode_rewards)/len(episode_rewards))
        if len(episode_rewards) >= 100:
            avg_reward = np.mean(episode_rewards[-100:]) 
            if rank == 0:
                print(f"Episode {episode}, Reward: {total_reward}, Avg Reward: {avg_reward}")


            with open('episode_rewards_noise.pkl', 'wb') as f:
                pickle.dump(episode_rewards, f)
            with open('avg_rewards_noise.pkl', 'wb') as f:
                pickle.dump(avg_reward_list, f)
                

            if avg_reward >= 500:
                if rank == 0:
                    print(f"Solved at episode {episode}: average reward of last 100 episodes is {avg_reward}")
                    torch.save(actor_critic.state_dict(), 'actor_critic_noise.pt')
                    print('Model saved.')
                break

    env.close()

# %%
env = CartPoleWind()
train_a3c(env, gamma=0.99, lr=0.001, max_episodes=500)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/envs/classic_control/cartpole.py:179: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gym/envs/classic_control/cartpole.py:179: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   logger.warn(
# Episode 99, Reward: 17.0, Avg Reward: 32.13
# Episode 100, Reward: 48.0, Avg Reward: 32.5
# Episode 101, Reward: 48.0, Avg Reward: 32.88
# Episode 102, Reward: 133.0, Avg Reward: 34.12
# Episode 103, Reward: 110.0, Avg Reward: 35.11
# Episode 104, Reward: 50.0, Avg Reward: 35.46
# Episode 105, Reward: 104.0, Avg Reward: 36.39
# Episode 106, Reward: 127.0, Avg Reward: 37.5
# Episode 107, Reward: 48.0, Avg Reward: 37.89
# Episode 108, Reward: 35.0, Avg Reward: 38.14
# Episode 109, Reward: 49.0, Avg Reward: 38.53
# Episode 110, Reward: 56.0, Avg Reward: 38.96
# Episode 111, Reward: 65.0, Avg Reward: 39.49
# Episode 112, Reward: 48.0, Avg Reward: 39.81
# Episode 113, Reward: 43.0, Avg Reward: 40.13
# Episode 114, Reward: 48.0, Avg Reward: 40.5
# Episode 115, Reward: 48.0, Avg Reward: 40.87
# Episode 116, Reward: 95.0, Avg Reward: 41.71
# Episode 117, Reward: 76.0, Avg Reward: 42.38
# Episode 118, Reward: 67.0, Avg Reward: 42.48
# Episode 119, Reward: 153.0, Avg Reward: 43.83
# Episode 120, Reward: 74.0, Avg Reward: 44.4
# Episode 121, Reward: 151.0, Avg Reward: 45.81
# Episode 122, Reward: 150.0, Avg Reward: 47.21
# Episode 123, Reward: 142.0, Avg Reward: 48.23
# Episode 124, Reward: 243.0, Avg Reward: 50.46
# Episode 125, Reward: 97.0, Avg Reward: 51.17
# Episode 126, Reward: 136.0, Avg Reward: 52.42
# Episode 127, Reward: 149.0, Avg Reward: 53.69
# Episode 128, Reward: 143.0, Avg Reward: 54.85
# Episode 129, Reward: 142.0, Avg Reward: 55.85
# Episode 130, Reward: 123.0, Avg Reward: 56.96
# Episode 131, Reward: 140.0, Avg Reward: 57.93
# Episode 132, Reward: 115.0, Avg Reward: 58.84
# Episode 133, Reward: 120.0, Avg Reward: 59.94
# Episode 134, Reward: 242.0, Avg Reward: 62.26
# Episode 135, Reward: 156.0, Avg Reward: 63.62
# Episode 136, Reward: 128.0, Avg Reward: 64.58
# Episode 137, Reward: 79.0, Avg Reward: 65.22
# Episode 138, Reward: 171.0, Avg Reward: 66.76
# Episode 139, Reward: 70.0, Avg Reward: 67.32
# Episode 140, Reward: 151.0, Avg Reward: 68.71
# Episode 141, Reward: 100.0, Avg Reward: 69.6
# Episode 142, Reward: 234.0, Avg Reward: 71.58
# Episode 143, Reward: 159.0, Avg Reward: 72.9
# Episode 144, Reward: 175.0, Avg Reward: 74.36
# Episode 145, Reward: 105.0, Avg Reward: 75.17
# Episode 146, Reward: 110.0, Avg Reward: 76.17
# Episode 147, Reward: 108.0, Avg Reward: 77.01
# Episode 148, Reward: 196.0, Avg Reward: 78.64
# Episode 149, Reward: 149.0, Avg Reward: 79.84
# Episode 150, Reward: 218.0, Avg Reward: 81.85
# Episode 151, Reward: 235.0, Avg Reward: 84.11
# Episode 152, Reward: 143.0, Avg Reward: 85.39
# Episode 153, Reward: 228.0, Avg Reward: 87.53
# Episode 154, Reward: 79.0, Avg Reward: 88.05
# Episode 155, Reward: 137.0, Avg Reward: 89.05
# Episode 156, Reward: 92.0, Avg Reward: 89.84
# Episode 157, Reward: 91.0, Avg Reward: 90.5
# Episode 158, Reward: 50.0, Avg Reward: 90.84
# Episode 159, Reward: 63.0, Avg Reward: 91.15
# Episode 160, Reward: 61.0, Avg Reward: 91.49
# Episode 161, Reward: 63.0, Avg Reward: 91.82
# Episode 162, Reward: 104.0, Avg Reward: 92.2
# Episode 163, Reward: 62.0, Avg Reward: 92.44
# Episode 164, Reward: 74.0, Avg Reward: 92.41
# Episode 165, Reward: 70.0, Avg Reward: 92.84
# Episode 166, Reward: 49.0, Avg Reward: 93.18
# Episode 167, Reward: 88.0, Avg Reward: 93.83
# Episode 168, Reward: 26.0, Avg Reward: 93.5
# Episode 169, Reward: 46.0, Avg Reward: 93.83
# Episode 170, Reward: 76.0, Avg Reward: 93.43
# Episode 171, Reward: 49.0, Avg Reward: 93.43
# Episode 172, Reward: 66.0, Avg Reward: 93.77
# Episode 173, Reward: 37.0, Avg Reward: 93.74
# Episode 174, Reward: 53.0, Avg Reward: 94.11
# Episode 175, Reward: 49.0, Avg Reward: 94.13
# Episode 176, Reward: 34.0, Avg Reward: 94.3
# Episode 177, Reward: 34.0, Avg Reward: 93.88
# Episode 178, Reward: 48.0, Avg Reward: 93.84
# Episode 179, Reward: 64.0, Avg Reward: 93.84
# Episode 180, Reward: 39.0, Avg Reward: 93.36
# Episode 181, Reward: 44.0, Avg Reward: 93.01
# Episode 182, Reward: 55.0, Avg Reward: 93.34
# Episode 183, Reward: 58.0, Avg Reward: 93.25
# Episode 184, Reward: 88.0, Avg Reward: 93.52
# Episode 185, Reward: 47.0, Avg Reward: 93.15
# Episode 186, Reward: 101.0, Avg Reward: 93.64
# Episode 187, Reward: 36.0, Avg Reward: 93.32
# Episode 188, Reward: 36.0, Avg Reward: 93.35
# Episode 189, Reward: 53.0, Avg Reward: 93.04
# Episode 190, Reward: 52.0, Avg Reward: 93.18
# Episode 191, Reward: 84.0, Avg Reward: 93.76
# Episode 192, Reward: 57.0, Avg Reward: 94.12
# Episode 193, Reward: 54.0, Avg Reward: 93.81
# Episode 194, Reward: 47.0, Avg Reward: 93.56
# Episode 195, Reward: 41.0, Avg Reward: 92.93
# Episode 196, Reward: 42.0, Avg Reward: 92.73
# Episode 197, Reward: 54.0, Avg Reward: 92.46
# Episode 198, Reward: 58.0, Avg Reward: 92.61
# Episode 199, Reward: 82.0, Avg Reward: 93.26
# Episode 200, Reward: 52.0, Avg Reward: 93.3
# Episode 201, Reward: 26.0, Avg Reward: 93.08
# Episode 202, Reward: 66.0, Avg Reward: 92.41
# Episode 203, Reward: 54.0, Avg Reward: 91.85
# Episode 204, Reward: 43.0, Avg Reward: 91.78
# Episode 205, Reward: 54.0, Avg Reward: 91.28
# Episode 206, Reward: 51.0, Avg Reward: 90.52
# Episode 207, Reward: 38.0, Avg Reward: 90.42
# Episode 208, Reward: 47.0, Avg Reward: 90.54
# Episode 209, Reward: 43.0, Avg Reward: 90.48
# Episode 210, Reward: 56.0, Avg Reward: 90.48
# Episode 211, Reward: 55.0, Avg Reward: 90.38
# Episode 212, Reward: 36.0, Avg Reward: 90.26
# Episode 213, Reward: 56.0, Avg Reward: 90.39
# Episode 214, Reward: 41.0, Avg Reward: 90.32
# Episode 215, Reward: 36.0, Avg Reward: 90.2
# Episode 216, Reward: 44.0, Avg Reward: 89.69
# Episode 217, Reward: 46.0, Avg Reward: 89.39
# Episode 218, Reward: 49.0, Avg Reward: 89.21
# Episode 219, Reward: 45.0, Avg Reward: 88.13
# Episode 220, Reward: 33.0, Avg Reward: 87.72
# Episode 221, Reward: 64.0, Avg Reward: 86.85
# Episode 222, Reward: 69.0, Avg Reward: 86.04
# Episode 223, Reward: 47.0, Avg Reward: 85.09
# Episode 224, Reward: 55.0, Avg Reward: 83.21
# Episode 225, Reward: 81.0, Avg Reward: 83.05
# Episode 226, Reward: 54.0, Avg Reward: 82.23
# Episode 227, Reward: 103.0, Avg Reward: 81.77
# Episode 228, Reward: 36.0, Avg Reward: 80.7
# Episode 229, Reward: 67.0, Avg Reward: 79.95
# Episode 230, Reward: 92.0, Avg Reward: 79.64
# Episode 231, Reward: 71.0, Avg Reward: 78.95
# Episode 232, Reward: 74.0, Avg Reward: 78.54
# Episode 233, Reward: 121.0, Avg Reward: 78.55
# Episode 234, Reward: 89.0, Avg Reward: 77.02
# Episode 235, Reward: 51.0, Avg Reward: 75.97
# Episode 236, Reward: 101.0, Avg Reward: 75.7
# Episode 237, Reward: 124.0, Avg Reward: 76.15
# Episode 238, Reward: 86.0, Avg Reward: 75.3
# Episode 239, Reward: 55.0, Avg Reward: 75.15
# Episode 240, Reward: 226.0, Avg Reward: 75.9
# Episode 241, Reward: 117.0, Avg Reward: 76.07
# Episode 242, Reward: 191.0, Avg Reward: 75.64
# Episode 243, Reward: 222.0, Avg Reward: 76.27
# Episode 244, Reward: 152.0, Avg Reward: 76.04
# Episode 245, Reward: 81.0, Avg Reward: 75.8
# Episode 246, Reward: 249.0, Avg Reward: 77.19
# Episode 247, Reward: 76.0, Avg Reward: 76.87
# Episode 248, Reward: 113.0, Avg Reward: 76.04
# Episode 249, Reward: 411.0, Avg Reward: 78.66
# Episode 250, Reward: 337.0, Avg Reward: 79.85
# Episode 251, Reward: 156.0, Avg Reward: 79.06
# Episode 252, Reward: 208.0, Avg Reward: 79.71
# Episode 253, Reward: 427.0, Avg Reward: 81.7
# Episode 254, Reward: 315.0, Avg Reward: 84.06
# Episode 255, Reward: 320.0, Avg Reward: 85.89
# Episode 256, Reward: 122.0, Avg Reward: 86.19
# Episode 257, Reward: 111.0, Avg Reward: 86.39
# Episode 258, Reward: 145.0, Avg Reward: 87.34
# Episode 259, Reward: 128.0, Avg Reward: 87.99
# Episode 260, Reward: 117.0, Avg Reward: 88.55
# Episode 261, Reward: 179.0, Avg Reward: 89.71
# Episode 262, Reward: 154.0, Avg Reward: 90.21
# Episode 263, Reward: 68.0, Avg Reward: 90.27
# Episode 264, Reward: 95.0, Avg Reward: 90.48
# Episode 265, Reward: 81.0, Avg Reward: 90.59
# Episode 266, Reward: 64.0, Avg Reward: 90.74
# Episode 267, Reward: 91.0, Avg Reward: 90.77
# Episode 268, Reward: 102.0, Avg Reward: 91.53
# Episode 269, Reward: 78.0, Avg Reward: 91.85
# Episode 270, Reward: 64.0, Avg Reward: 91.73
# Episode 271, Reward: 77.0, Avg Reward: 92.01
# Episode 272, Reward: 66.0, Avg Reward: 92.01
# Episode 273, Reward: 77.0, Avg Reward: 92.41
# Episode 274, Reward: 55.0, Avg Reward: 92.43
# Episode 275, Reward: 79.0, Avg Reward: 92.73
# Episode 276, Reward: 79.0, Avg Reward: 93.18
# Episode 277, Reward: 78.0, Avg Reward: 93.62
# Episode 278, Reward: 122.0, Avg Reward: 94.36
# Episode 279, Reward: 118.0, Avg Reward: 94.9
# Episode 280, Reward: 79.0, Avg Reward: 95.3
# Episode 281, Reward: 103.0, Avg Reward: 95.89
# Episode 282, Reward: 56.0, Avg Reward: 95.9
# Episode 283, Reward: 92.0, Avg Reward: 96.24
# Episode 284, Reward: 75.0, Avg Reward: 96.11
# Episode 285, Reward: 63.0, Avg Reward: 96.27
# Episode 286, Reward: 122.0, Avg Reward: 96.48
# Episode 287, Reward: 69.0, Avg Reward: 96.81
# Episode 288, Reward: 82.0, Avg Reward: 97.27
# Episode 289, Reward: 81.0, Avg Reward: 97.55
# Episode 290, Reward: 87.0, Avg Reward: 97.9
# Episode 291, Reward: 65.0, Avg Reward: 97.71
# Episode 292, Reward: 86.0, Avg Reward: 98.0
# Episode 293, Reward: 93.0, Avg Reward: 98.39
# Episode 294, Reward: 85.0, Avg Reward: 98.77
# Episode 295, Reward: 80.0, Avg Reward: 99.16
# Episode 296, Reward: 68.0, Avg Reward: 99.42
# Episode 297, Reward: 59.0, Avg Reward: 99.47
# Episode 298, Reward: 57.0, Avg Reward: 99.46
# Episode 299, Reward: 42.0, Avg Reward: 99.06
# Episode 300, Reward: 52.0, Avg Reward: 99.06
# Episode 301, Reward: 37.0, Avg Reward: 99.17
# Episode 302, Reward: 62.0, Avg Reward: 99.13
# Episode 303, Reward: 67.0, Avg Reward: 99.26
# Episode 304, Reward: 90.0, Avg Reward: 99.73
# Episode 305, Reward: 116.0, Avg Reward: 100.35
# Episode 306, Reward: 83.0, Avg Reward: 100.67
# Episode 307, Reward: 95.0, Avg Reward: 101.24
# Episode 308, Reward: 85.0, Avg Reward: 101.62
# Episode 309, Reward: 112.0, Avg Reward: 102.31
# Episode 310, Reward: 76.0, Avg Reward: 102.51
# Episode 311, Reward: 49.0, Avg Reward: 102.45
# Episode 312, Reward: 57.0, Avg Reward: 102.66
# Episode 313, Reward: 78.0, Avg Reward: 102.88
# Episode 314, Reward: 94.0, Avg Reward: 103.41
# Episode 315, Reward: 118.0, Avg Reward: 104.23
# Episode 316, Reward: 61.0, Avg Reward: 104.4
# Episode 317, Reward: 75.0, Avg Reward: 104.69
# Episode 318, Reward: 82.0, Avg Reward: 105.02
# Episode 319, Reward: 71.0, Avg Reward: 105.28
# Episode 320, Reward: 76.0, Avg Reward: 105.71
# Episode 321, Reward: 106.0, Avg Reward: 106.13
# Episode 322, Reward: 72.0, Avg Reward: 106.16
# Episode 323, Reward: 94.0, Avg Reward: 106.63
# Episode 324, Reward: 94.0, Avg Reward: 107.02
# Episode 325, Reward: 111.0, Avg Reward: 107.32
# Episode 326, Reward: 115.0, Avg Reward: 107.93
# Episode 327, Reward: 131.0, Avg Reward: 108.21
# Episode 328, Reward: 172.0, Avg Reward: 109.57
# Episode 329, Reward: 374.0, Avg Reward: 112.64
# Episode 330, Reward: 206.0, Avg Reward: 113.78
# Episode 331, Reward: 195.0, Avg Reward: 115.02
# Episode 332, Reward: 237.0, Avg Reward: 116.65
# Episode 333, Reward: 273.0, Avg Reward: 118.17
# Episode 334, Reward: 493.0, Avg Reward: 122.21
# Episode 335, Reward: 464.0, Avg Reward: 126.34
# Episode 336, Reward: 169.0, Avg Reward: 127.02
# Episode 337, Reward: 187.0, Avg Reward: 127.65
# Episode 338, Reward: 247.0, Avg Reward: 129.26
# Episode 339, Reward: 500.0, Avg Reward: 133.71
# Episode 340, Reward: 109.0, Avg Reward: 132.54
# Episode 341, Reward: 145.0, Avg Reward: 132.82
# Episode 342, Reward: 156.0, Avg Reward: 132.47
# Episode 343, Reward: 173.0, Avg Reward: 131.98
# Episode 344, Reward: 163.0, Avg Reward: 132.09
# Episode 345, Reward: 137.0, Avg Reward: 132.65
# Episode 346, Reward: 202.0, Avg Reward: 132.18
# Episode 347, Reward: 146.0, Avg Reward: 132.88
# Episode 348, Reward: 182.0, Avg Reward: 133.57
# Episode 349, Reward: 472.0, Avg Reward: 134.18
# Episode 350, Reward: 305.0, Avg Reward: 133.86
# Episode 351, Reward: 448.0, Avg Reward: 136.78
# Episode 352, Reward: 287.0, Avg Reward: 137.57
# Episode 353, Reward: 325.0, Avg Reward: 136.55
# Episode 354, Reward: 226.0, Avg Reward: 135.66
# Episode 355, Reward: 216.0, Avg Reward: 134.62
# Episode 356, Reward: 193.0, Avg Reward: 135.33
# Episode 357, Reward: 473.0, Avg Reward: 138.95
# Episode 358, Reward: 223.0, Avg Reward: 139.73
# Episode 359, Reward: 339.0, Avg Reward: 141.84
# Episode 360, Reward: 423.0, Avg Reward: 144.9
# Episode 361, Reward: 291.0, Avg Reward: 146.02
# Episode 362, Reward: 301.0, Avg Reward: 147.49
# Episode 363, Reward: 165.0, Avg Reward: 148.46
# Episode 364, Reward: 213.0, Avg Reward: 149.64
# Episode 365, Reward: 214.0, Avg Reward: 150.97
# Episode 366, Reward: 135.0, Avg Reward: 151.68
# Episode 367, Reward: 169.0, Avg Reward: 152.46
# Episode 368, Reward: 140.0, Avg Reward: 152.84
# Episode 369, Reward: 137.0, Avg Reward: 153.43
# Episode 370, Reward: 108.0, Avg Reward: 153.87
# Episode 371, Reward: 126.0, Avg Reward: 154.36
# Episode 372, Reward: 126.0, Avg Reward: 154.96
# Episode 373, Reward: 186.0, Avg Reward: 156.05
# Episode 374, Reward: 187.0, Avg Reward: 157.37
# Episode 375, Reward: 157.0, Avg Reward: 158.15
# Episode 376, Reward: 119.0, Avg Reward: 158.55
# Episode 377, Reward: 150.0, Avg Reward: 159.27
# Episode 378, Reward: 126.0, Avg Reward: 159.31
# Episode 379, Reward: 115.0, Avg Reward: 159.28
# Episode 380, Reward: 41.0, Avg Reward: 158.9
# Episode 381, Reward: 88.0, Avg Reward: 158.75
# Episode 382, Reward: 80.0, Avg Reward: 158.99
# Episode 383, Reward: 122.0, Avg Reward: 159.29
# Episode 384, Reward: 84.0, Avg Reward: 159.38
# Episode 385, Reward: 115.0, Avg Reward: 159.9
# Episode 386, Reward: 98.0, Avg Reward: 159.66
# Episode 387, Reward: 108.0, Avg Reward: 160.05
# Episode 388, Reward: 93.0, Avg Reward: 160.16
# Episode 389, Reward: 93.0, Avg Reward: 160.28
# Episode 390, Reward: 104.0, Avg Reward: 160.45
# Episode 391, Reward: 111.0, Avg Reward: 160.91
# Episode 392, Reward: 64.0, Avg Reward: 160.69
# Episode 393, Reward: 120.0, Avg Reward: 160.96
# Episode 394, Reward: 117.0, Avg Reward: 161.28
# Episode 395, Reward: 112.0, Avg Reward: 161.6
# Episode 396, Reward: 135.0, Avg Reward: 162.27
# Episode 397, Reward: 86.0, Avg Reward: 162.54
# Episode 398, Reward: 150.0, Avg Reward: 163.47
# Episode 399, Reward: 119.0, Avg Reward: 164.24
# Episode 400, Reward: 141.0, Avg Reward: 165.13
# Episode 401, Reward: 158.0, Avg Reward: 166.34
# Episode 402, Reward: 164.0, Avg Reward: 167.36
# Episode 403, Reward: 232.0, Avg Reward: 169.01
# Episode 404, Reward: 209.0, Avg Reward: 170.2
# Episode 405, Reward: 173.0, Avg Reward: 170.77
# Episode 406, Reward: 346.0, Avg Reward: 173.4
# Episode 407, Reward: 244.0, Avg Reward: 174.89
# Episode 408, Reward: 501.0, Avg Reward: 179.05
# Episode 409, Reward: 180.0, Avg Reward: 179.73
# Episode 410, Reward: 160.0, Avg Reward: 180.57
# Episode 411, Reward: 293.0, Avg Reward: 183.01
# Episode 412, Reward: 278.0, Avg Reward: 185.22
# Episode 413, Reward: 263.0, Avg Reward: 187.07
# Episode 414, Reward: 277.0, Avg Reward: 188.9
# Episode 415, Reward: 185.0, Avg Reward: 189.57
# Episode 416, Reward: 262.0, Avg Reward: 191.58
# Episode 417, Reward: 488.0, Avg Reward: 195.71
# Episode 418, Reward: 138.0, Avg Reward: 196.27
# Episode 419, Reward: 163.0, Avg Reward: 197.19
# Episode 420, Reward: 146.0, Avg Reward: 197.89
# Episode 421, Reward: 333.0, Avg Reward: 200.16
# Episode 422, Reward: 173.0, Avg Reward: 201.17
# Episode 423, Reward: 95.0, Avg Reward: 201.18
# Episode 424, Reward: 194.0, Avg Reward: 202.18
# Episode 425, Reward: 164.0, Avg Reward: 202.71
# Episode 426, Reward: 220.0, Avg Reward: 203.76
# Episode 427, Reward: 165.0, Avg Reward: 204.1
# Episode 428, Reward: 174.0, Avg Reward: 204.12
# Episode 429, Reward: 142.0, Avg Reward: 201.8
# Episode 430, Reward: 121.0, Avg Reward: 200.95
# Episode 431, Reward: 152.0, Avg Reward: 200.52
# Episode 432, Reward: 144.0, Avg Reward: 199.59
# Episode 433, Reward: 142.0, Avg Reward: 198.28
# Episode 434, Reward: 322.0, Avg Reward: 196.57
# Episode 435, Reward: 177.0, Avg Reward: 193.7
# Episode 436, Reward: 272.0, Avg Reward: 194.73
# Episode 437, Reward: 319.0, Avg Reward: 196.05
# Episode 438, Reward: 501.0, Avg Reward: 198.59
# Episode 439, Reward: 326.0, Avg Reward: 196.85
# Episode 440, Reward: 500.0, Avg Reward: 200.76
# Episode 441, Reward: 500.0, Avg Reward: 204.31
# Episode 442, Reward: 375.0, Avg Reward: 206.5
# Episode 443, Reward: 213.0, Avg Reward: 206.9
# Episode 444, Reward: 243.0, Avg Reward: 207.7
# Episode 445, Reward: 288.0, Avg Reward: 209.21
# Episode 446, Reward: 192.0, Avg Reward: 209.11
# Episode 447, Reward: 167.0, Avg Reward: 209.32
# Episode 448, Reward: 138.0, Avg Reward: 208.88
# Episode 449, Reward: 179.0, Avg Reward: 205.95
# Episode 450, Reward: 170.0, Avg Reward: 204.6
# Episode 451, Reward: 192.0, Avg Reward: 202.04
# Episode 452, Reward: 332.0, Avg Reward: 202.49
# Episode 453, Reward: 351.0, Avg Reward: 202.75
# Episode 454, Reward: 207.0, Avg Reward: 202.56
# Episode 455, Reward: 500.0, Avg Reward: 205.4
# Episode 456, Reward: 391.0, Avg Reward: 207.38
# Episode 457, Reward: 262.0, Avg Reward: 205.27
# Episode 458, Reward: 197.0, Avg Reward: 205.01
# Episode 459, Reward: 262.0, Avg Reward: 204.24
# Episode 460, Reward: 133.0, Avg Reward: 201.34
# Episode 461, Reward: 179.0, Avg Reward: 200.22
# Episode 462, Reward: 144.0, Avg Reward: 198.65
# Episode 463, Reward: 208.0, Avg Reward: 199.08
# Episode 464, Reward: 232.0, Avg Reward: 199.27
# Episode 465, Reward: 160.0, Avg Reward: 198.73
# Episode 466, Reward: 133.0, Avg Reward: 198.71
# Episode 467, Reward: 132.0, Avg Reward: 198.34
# Episode 468, Reward: 170.0, Avg Reward: 198.64
# Episode 469, Reward: 157.0, Avg Reward: 198.84
# Episode 470, Reward: 220.0, Avg Reward: 199.96
# Episode 471, Reward: 154.0, Avg Reward: 200.24
# Episode 472, Reward: 173.0, Avg Reward: 200.71
# Episode 473, Reward: 184.0, Avg Reward: 200.69
# Episode 474, Reward: 210.0, Avg Reward: 200.92
# Episode 475, Reward: 204.0, Avg Reward: 201.39
# Episode 476, Reward: 194.0, Avg Reward: 202.14
# Episode 477, Reward: 259.0, Avg Reward: 203.23
# Episode 478, Reward: 317.0, Avg Reward: 205.14
# Episode 479, Reward: 238.0, Avg Reward: 206.37
# Episode 480, Reward: 272.0, Avg Reward: 208.68
# Episode 481, Reward: 260.0, Avg Reward: 210.4
# Episode 482, Reward: 501.0, Avg Reward: 214.61
# Episode 483, Reward: 500.0, Avg Reward: 218.39
# Episode 484, Reward: 500.0, Avg Reward: 222.55
# Episode 485, Reward: 501.0, Avg Reward: 226.41
# Episode 486, Reward: 500.0, Avg Reward: 230.43
# Episode 487, Reward: 500.0, Avg Reward: 234.35
# Episode 488, Reward: 500.0, Avg Reward: 238.42
# Episode 489, Reward: 501.0, Avg Reward: 242.5
# Episode 490, Reward: 500.0, Avg Reward: 246.46
# Episode 491, Reward: 500.0, Avg Reward: 250.35
# Episode 492, Reward: 500.0, Avg Reward: 254.71
# Episode 493, Reward: 385.0, Avg Reward: 257.36
# Episode 494, Reward: 328.0, Avg Reward: 259.47
# Episode 495, Reward: 367.0, Avg Reward: 262.02
# Episode 496, Reward: 489.0, Avg Reward: 265.56
# Episode 497, Reward: 340.0, Avg Reward: 268.1
# Episode 498, Reward: 501.0, Avg Reward: 271.61
# Episode 499, Reward: 284.0, Avg Reward: 273.26
# Model saved.

# %%
import pickle
import matplotlib.pyplot as plt
import torch
env = CartPoleWind()
def evaluate_model(model, env, num_episodes):
    episode_rewards = []
    for episode in range(num_episodes):
        state = env.reset()
        done = False
        total_reward = 0
        while not done:
          action = select_action(model, state)
          env_list = env.step(action)
          observation = env_list[0]
          reward = env_list[1]
          done = env_list[2]
          _ = env_list[3]
          total_reward += reward
        # while not done:
        #     state = torch.from_numpy(state).float().unsqueeze(0)
        #     with torch.no_grad():
        #         value, action_probs = evaluate_action(state)
        #     action = torch.argmax(action_probs).item()
            # with torch.no_grad():
            #     # state_tensor = torch.FloatTensor(state)
            #     # action_probs = model(state_tensor)
            #     # print(type(action_probs))
            #     # action = torch.argmax(action_probs).item()
          env_list = env.step(action)
          next_state = env_list[0]
          reward = env_list[1]
          done = env_list[2]
          _ = env_list[3]
          total_reward += reward
          state = next_state
        episode_rewards.append(total_reward)
    return episode_rewards


model = ActorCritic(env.observation_space.shape[0], env.action_space.n)
model.load_state_dict(torch.load('actor_critic_noise.pt'))


env = CartPoleWind()
episode_rewards = evaluate_model(model, env, num_episodes=100)

with open('episode_rewards_eval_noise.pkl', 'wb') as f:
    pickle.dump(episode_rewards, f)


plt.figure()
plt.plot(episode_rewards)
plt.title("Episode Rewards of Greedy Policy")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/envs/classic_control/cartpole.py:179: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   logger.warn(
