# %% [markdown]
# #DQN Cart Pole Noise Environment

# %%
# !pip install gymnasium
# !pip3 install gymnasium[classic_control]

import gymnasium as gym
import torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gymnasium[classic_control] in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (0.0.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (4.5.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (1.0.0)
# Requirement already satisfied: pygame==2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (2.1.3)

# %%
# Wind noise function
def wind_noise(action):
    wind_direction = np.random.randint(0, 3)
    double_action = False
    
    if wind_direction == 0:  # no wind
        wind_action = action
    
    # Wind blows in the left direction and left action is taken
    elif wind_direction == 1 and action == 0:
            wind_action = 0  # left action
            double_action = True
    
    # Wind blows in the right direction and right action is taken
    elif wind_direction == 2 and action == 1:
            wind_action = 1  # Right action
            double_action = True
            
    else:
        wind_action = action # no wind_action

    return double_action, wind_action

# Modified environment step function 
def modified_env_step(environment, action):
    # Check action caused by wind
    double_action, wind_action = wind_noise(action)

    # Take steps
    if not double_action:
        observation, reward, terminated, truncated, info = environment.step(wind_action)
    else:
        observation, reward1, terminated, truncated, info = environment.step(action)
        if (terminated or truncated):
            reward = reward1
        else:
            observation, reward2, terminated, truncated, info = environment.step(wind_action)
            reward = reward1 + reward2

    return observation, reward, terminated, truncated, info

# %%
env = gym.make('CartPole-v1')

obs, info = env.reset()

obs_space = env.observation_space.shape[0]
action_space = env.action_space.n

obs, info, obs_space, action_space
# Out:
# (array([-0.02317856, -0.04430171, -0.0148507 , -0.03444682], dtype=float32),
#  {},
#  4,
#  2)

# %%
class DQNnn(torch.nn.Module):
    def __init__(self) -> None:
        super().__init__()
        self.linear_relu_stack = torch.nn.Sequential(
            torch.nn.Linear(obs_space, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, action_space)
        )
    def forward(self, x):
        return self.linear_relu_stack(x)

nn_first = DQNnn()
nn_second = DQNnn()
dict_load = nn_first.state_dict()
nn_second.load_state_dict(dict_load)

nn_first, nn_second
# Out:
# (DQNnn(
#    (linear_relu_stack): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#      (4): Linear(in_features=256, out_features=2, bias=True)
#    )
#  ),
#  DQNnn(
#    (linear_relu_stack): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#      (4): Linear(in_features=256, out_features=2, bias=True)
#    )
#  ))

# %%
import random
import numpy as np

from collections import deque
buffer_memory = deque(maxlen = 10000)

def policy_cal(obs):
  random_val = random.random()
  epsilon_val = epsilon_cal()
  if random_val > epsilon_val:
    action_type = 'greedy'
    obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
    action_val = nn_first(obs_tensor).detach().numpy()
    action_val = np.argmax(action_val)
    return action_val, action_type
  else:
    action_type = 'random'
    action_val = env.action_space.sample()
    return action_val, action_type

def policy_learnt(obs):
  action_type = 'greedy'
  obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
  action_val = nn_first(obs_tensor).detach().numpy()
  action_val = np.argmax(action_val)
  return action_val, action_type

import math
epsilon_steps = 0
def epsilon_cal():
  diff_val = 1.0 - 0.05
  global epsilon_steps
  exp_val = math.exp(-1.0 * epsilon_steps / 1000)
  epsilon_steps += 1
  epsilon_val = 0.05 + diff_val * exp_val
  return epsilon_val

optimizer_param = nn_first.parameters()
optimizer = torch.optim.AdamW(optimizer_param, lr=1e-4, amsgrad=True)

# %%
def experience_cal():
  if len(buffer_memory) < 128:
    return
  
  buffer_batch = random.sample(buffer_memory, 128)
  batch_obs1, batch_obs2 = [], []
  batch_reward, batch_action = [], []
  batch_completed = []

  for val in buffer_batch:
    obs1_val, obs2_val, reward_val, action_val, completed_val = val
    batch_completed.append(completed_val)
    batch_obs1.append(obs1_val)
    batch_obs2.append(obs2_val)
    batch_action.append([action_val])
    batch_reward.append(reward_val)    
  
  batch_obs2_nf = []
  for i in range(len(batch_completed)):
    if batch_completed[i]:
      batch_obs2_nf.append(batch_obs2[i])
  
  batch_completed = torch.tensor(batch_completed, dtype=torch.bool) # 128
  batch_obs1 = torch.tensor(batch_obs1) # 128
  batch_obs2 = torch.tensor(batch_obs2) # 128
  batch_obs2_nf = torch.tensor(batch_obs2_nf) # < 128
  batch_action = torch.tensor(batch_action, dtype=torch.int64) # 128
  batch_reward = torch.tensor(batch_reward) # 128
  
  obs1_qval = nn_first(batch_obs1).gather(1, batch_action)

  batch_obs2_val = torch.zeros(128)
  with torch.set_grad_enabled(False):
    max_val_list = nn_second(batch_obs2_nf).detach()
    max_val = max_val_list.max(1)[0]
    batch_obs2_val[batch_completed] = max_val

  discounted_reward = 0.99 * batch_obs2_val
  obs2_qval = batch_reward + discounted_reward
  
  loss_function = torch.nn.SmoothL1Loss()
  criterion = loss_function
  loss_param1 = obs1_qval
  loss_param2 = obs2_qval[:, None]
  loss = criterion(loss_param1, loss_param2)

  optimizer.zero_grad()
  loss.backward()
  
  grad_max_val = 100
  grad_model_param = nn_first.parameters()
  torch.nn.utils.clip_grad_value_(grad_model_param, grad_max_val)
  
  optimizer.step()

  update_cf1 = 0.005
  update_cf2 = 1 - 0.005
  nn_first_dict = nn_first.state_dict()
  nn_second_dict = nn_second.state_dict()
  for dict_key in nn_first.state_dict():
    nn_first_update = update_cf1 * nn_first_dict[dict_key]
    nn_second_update = update_cf2 * nn_second_dict[dict_key]
    update_val = nn_first_update + nn_second_update
    nn_second_dict[dict_key] = update_val
  nn_second.load_state_dict(nn_second_dict)

# %%
rewards = []
for episode in range(500):
  obs1_val, info_val = env.reset()
  completed, term_val, trunc_val = False, False, False
  score, greedy_count, random_count = 0, 0, 0

  while not completed:
    action_val, action_type = policy_cal(obs1_val)
    if action_type == 'greedy':
      greedy_count += 1
    else:
      random_count += 1
  
    # modified_env_step function
    obs2_val, reward_val, term_val, trunc_val, info_val = modified_env_step(env, action_val)
    score += reward_val

    completed = term_val or trunc_val
    completed_val = not completed

    experience = (obs1_val, obs2_val, reward_val, action_val, completed_val)
    buffer_memory.append(experience)
    obs1_val = obs2_val

    experience_cal()

    if completed:
      print(f'Episode: {episode}, Score: {score}, Random: {random_count}, Greedy: {greedy_count}')
      rewards.append(score)
      break
# Out:
# Episode: 0, Score: 32.0, Random: 19, Greedy: 1
# Episode: 1, Score: 30.0, Random: 21, Greedy: 0
# Episode: 2, Score: 11.0, Random: 9, Greedy: 1
# Episode: 3, Score: 17.0, Random: 14, Greedy: 0
# Episode: 4, Score: 10.0, Random: 7, Greedy: 1
# Episode: 5, Score: 26.0, Random: 19, Greedy: 1
# Episode: 6, Score: 27.0, Random: 19, Greedy: 2
# Episode: 7, Score: 9.0, Random: 7, Greedy: 0
# Episode: 8, Score: 18.0, Random: 13, Greedy: 2
# <ipython-input-6-cfebd45f9855>:24: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   batch_obs1 = torch.tensor(batch_obs1) # 128
# Episode: 9, Score: 20.0, Random: 13, Greedy: 2
# Episode: 10, Score: 19.0, Random: 14, Greedy: 1
# Episode: 11, Score: 11.0, Random: 9, Greedy: 0
# Episode: 12, Score: 10.0, Random: 4, Greedy: 3
# Episode: 13, Score: 14.0, Random: 11, Greedy: 1
# Episode: 14, Score: 11.0, Random: 7, Greedy: 2
# Episode: 15, Score: 13.0, Random: 8, Greedy: 3
# Episode: 16, Score: 15.0, Random: 9, Greedy: 2
# Episode: 17, Score: 14.0, Random: 7, Greedy: 2
# Episode: 18, Score: 30.0, Random: 18, Greedy: 6
# Episode: 19, Score: 12.0, Random: 8, Greedy: 2
# Episode: 20, Score: 12.0, Random: 6, Greedy: 2
# Episode: 21, Score: 31.0, Random: 18, Greedy: 3
# Episode: 22, Score: 35.0, Random: 25, Greedy: 4
# Episode: 23, Score: 8.0, Random: 3, Greedy: 3
# Episode: 24, Score: 13.0, Random: 5, Greedy: 3
# Episode: 25, Score: 21.0, Random: 8, Greedy: 6
# Episode: 26, Score: 25.0, Random: 13, Greedy: 5
# Episode: 27, Score: 10.0, Random: 6, Greedy: 2
# Episode: 28, Score: 18.0, Random: 6, Greedy: 9
# Episode: 29, Score: 11.0, Random: 4, Greedy: 3
# Episode: 30, Score: 11.0, Random: 6, Greedy: 1
# Episode: 31, Score: 11.0, Random: 5, Greedy: 3
# Episode: 32, Score: 9.0, Random: 3, Greedy: 4
# Episode: 33, Score: 11.0, Random: 4, Greedy: 3
# Episode: 34, Score: 26.0, Random: 15, Greedy: 6
# Episode: 35, Score: 11.0, Random: 5, Greedy: 3
# Episode: 36, Score: 18.0, Random: 11, Greedy: 4
# Episode: 37, Score: 10.0, Random: 6, Greedy: 1
# Episode: 38, Score: 13.0, Random: 7, Greedy: 4
# Episode: 39, Score: 12.0, Random: 7, Greedy: 2
# Episode: 40, Score: 9.0, Random: 4, Greedy: 2
# Episode: 41, Score: 12.0, Random: 5, Greedy: 4
# Episode: 42, Score: 12.0, Random: 6, Greedy: 3
# Episode: 43, Score: 16.0, Random: 8, Greedy: 3
# Episode: 44, Score: 17.0, Random: 6, Greedy: 6
# Episode: 45, Score: 10.0, Random: 3, Greedy: 5
# Episode: 46, Score: 15.0, Random: 7, Greedy: 4
# Episode: 47, Score: 10.0, Random: 4, Greedy: 4
# Episode: 48, Score: 16.0, Random: 9, Greedy: 3
# Episode: 49, Score: 16.0, Random: 10, Greedy: 4
# Episode: 50, Score: 14.0, Random: 5, Greedy: 6
# Episode: 51, Score: 11.0, Random: 3, Greedy: 5
# Episode: 52, Score: 15.0, Random: 6, Greedy: 4
# Episode: 53, Score: 11.0, Random: 6, Greedy: 3
# Episode: 54, Score: 19.0, Random: 7, Greedy: 9
# Episode: 55, Score: 17.0, Random: 6, Greedy: 6
# Episode: 56, Score: 18.0, Random: 5, Greedy: 8
# Episode: 57, Score: 11.0, Random: 5, Greedy: 5
# Episode: 58, Score: 9.0, Random: 3, Greedy: 3
# Episode: 59, Score: 37.0, Random: 14, Greedy: 16
# Episode: 60, Score: 12.0, Random: 4, Greedy: 5
# Episode: 61, Score: 11.0, Random: 3, Greedy: 4
# Episode: 62, Score: 23.0, Random: 10, Greedy: 7
# Episode: 63, Score: 13.0, Random: 3, Greedy: 6
# Episode: 64, Score: 15.0, Random: 10, Greedy: 1
# Episode: 65, Score: 17.0, Random: 8, Greedy: 5
# Episode: 66, Score: 36.0, Random: 14, Greedy: 15
# Episode: 67, Score: 35.0, Random: 15, Greedy: 12
# Episode: 68, Score: 23.0, Random: 11, Greedy: 9
# Episode: 69, Score: 11.0, Random: 3, Greedy: 5
# Episode: 70, Score: 29.0, Random: 9, Greedy: 12
# Episode: 71, Score: 9.0, Random: 3, Greedy: 4
# Episode: 72, Score: 51.0, Random: 13, Greedy: 23
# Episode: 73, Score: 67.0, Random: 23, Greedy: 28
# Episode: 74, Score: 41.0, Random: 10, Greedy: 22
# Episode: 75, Score: 15.0, Random: 4, Greedy: 8
# Episode: 76, Score: 59.0, Random: 21, Greedy: 29
# Episode: 77, Score: 56.0, Random: 16, Greedy: 31
# Episode: 78, Score: 28.0, Random: 8, Greedy: 14
# Episode: 79, Score: 15.0, Random: 5, Greedy: 8
# Episode: 80, Score: 63.0, Random: 17, Greedy: 33
# Episode: 81, Score: 109.0, Random: 29, Greedy: 52
# Episode: 82, Score: 18.0, Random: 9, Greedy: 4
# Episode: 83, Score: 262.0, Random: 44, Greedy: 157
# Episode: 84, Score: 201.0, Random: 29, Greedy: 117
# Episode: 85, Score: 106.0, Random: 16, Greedy: 66
# Episode: 86, Score: 171.0, Random: 24, Greedy: 97
# Episode: 87, Score: 162.0, Random: 22, Greedy: 91
# Episode: 88, Score: 174.0, Random: 17, Greedy: 117
# Episode: 89, Score: 304.0, Random: 35, Greedy: 199
# Episode: 90, Score: 140.0, Random: 11, Greedy: 98
# Episode: 91, Score: 127.0, Random: 18, Greedy: 80
# Episode: 92, Score: 121.0, Random: 7, Greedy: 85
# Episode: 93, Score: 140.0, Random: 9, Greedy: 94
# Episode: 94, Score: 137.0, Random: 6, Greedy: 99
# Episode: 95, Score: 124.0, Random: 8, Greedy: 86
# Episode: 96, Score: 174.0, Random: 10, Greedy: 114
# Episode: 97, Score: 296.0, Random: 24, Greedy: 193
# Episode: 98, Score: 114.0, Random: 5, Greedy: 83
# Episode: 99, Score: 291.0, Random: 5, Greedy: 215
# Episode: 100, Score: 115.0, Random: 7, Greedy: 79
# Episode: 101, Score: 143.0, Random: 5, Greedy: 101
# Episode: 102, Score: 107.0, Random: 4, Greedy: 81
# Episode: 103, Score: 103.0, Random: 4, Greedy: 77
# Episode: 104, Score: 136.0, Random: 6, Greedy: 96
# Episode: 105, Score: 142.0, Random: 9, Greedy: 107
# Episode: 106, Score: 207.0, Random: 7, Greedy: 153
# Episode: 107, Score: 85.0, Random: 7, Greedy: 60
# Episode: 108, Score: 281.0, Random: 14, Greedy: 193
# Episode: 109, Score: 148.0, Random: 6, Greedy: 102
# Episode: 110, Score: 168.0, Random: 7, Greedy: 123
# Episode: 111, Score: 380.0, Random: 13, Greedy: 272
# Episode: 112, Score: 134.0, Random: 9, Greedy: 92
# Episode: 113, Score: 253.0, Random: 9, Greedy: 186
# Episode: 114, Score: 156.0, Random: 8, Greedy: 107
# Episode: 115, Score: 146.0, Random: 7, Greedy: 104
# Episode: 116, Score: 156.0, Random: 5, Greedy: 114
# Episode: 117, Score: 125.0, Random: 8, Greedy: 82
# Episode: 118, Score: 164.0, Random: 6, Greedy: 113
# Episode: 119, Score: 125.0, Random: 2, Greedy: 92
# Episode: 120, Score: 202.0, Random: 12, Greedy: 138
# Episode: 121, Score: 141.0, Random: 4, Greedy: 104
# Episode: 122, Score: 249.0, Random: 7, Greedy: 173
# Episode: 123, Score: 241.0, Random: 4, Greedy: 178
# Episode: 124, Score: 153.0, Random: 11, Greedy: 115
# Episode: 125, Score: 134.0, Random: 6, Greedy: 95
# Episode: 126, Score: 197.0, Random: 12, Greedy: 142
# Episode: 127, Score: 177.0, Random: 6, Greedy: 132
# Episode: 128, Score: 132.0, Random: 1, Greedy: 97
# Episode: 129, Score: 138.0, Random: 5, Greedy: 95
# Episode: 130, Score: 170.0, Random: 2, Greedy: 127
# Episode: 131, Score: 150.0, Random: 7, Greedy: 102
# Episode: 132, Score: 179.0, Random: 10, Greedy: 125
# Episode: 133, Score: 150.0, Random: 8, Greedy: 101
# Episode: 134, Score: 146.0, Random: 4, Greedy: 106
# Episode: 135, Score: 138.0, Random: 4, Greedy: 101
# Episode: 136, Score: 223.0, Random: 7, Greedy: 161
# Episode: 137, Score: 216.0, Random: 3, Greedy: 158
# Episode: 138, Score: 138.0, Random: 4, Greedy: 96
# Episode: 139, Score: 167.0, Random: 6, Greedy: 118
# Episode: 140, Score: 196.0, Random: 6, Greedy: 139
# Episode: 141, Score: 151.0, Random: 4, Greedy: 115
# Episode: 142, Score: 139.0, Random: 8, Greedy: 95
# Episode: 143, Score: 147.0, Random: 7, Greedy: 102
# Episode: 144, Score: 182.0, Random: 8, Greedy: 124
# Episode: 145, Score: 170.0, Random: 7, Greedy: 120
# Episode: 146, Score: 118.0, Random: 3, Greedy: 89
# Episode: 147, Score: 139.0, Random: 7, Greedy: 102
# Episode: 148, Score: 149.0, Random: 8, Greedy: 107
# Episode: 149, Score: 129.0, Random: 7, Greedy: 90
# Episode: 150, Score: 138.0, Random: 7, Greedy: 101
# Episode: 151, Score: 142.0, Random: 11, Greedy: 102
# Episode: 152, Score: 116.0, Random: 4, Greedy: 84
# Episode: 153, Score: 151.0, Random: 5, Greedy: 99
# Episode: 154, Score: 131.0, Random: 6, Greedy: 92
# Episode: 155, Score: 183.0, Random: 10, Greedy: 127
# Episode: 156, Score: 239.0, Random: 10, Greedy: 170
# Episode: 157, Score: 254.0, Random: 9, Greedy: 181
# Episode: 158, Score: 175.0, Random: 8, Greedy: 120
# Episode: 159, Score: 129.0, Random: 3, Greedy: 89
# Episode: 160, Score: 142.0, Random: 5, Greedy: 106
# Episode: 161, Score: 180.0, Random: 9, Greedy: 120
# Episode: 162, Score: 151.0, Random: 4, Greedy: 108
# Episode: 163, Score: 154.0, Random: 6, Greedy: 108
# Episode: 164, Score: 136.0, Random: 6, Greedy: 90
# Episode: 165, Score: 114.0, Random: 3, Greedy: 83
# Episode: 166, Score: 167.0, Random: 5, Greedy: 118
# Episode: 167, Score: 159.0, Random: 6, Greedy: 113
# Episode: 168, Score: 160.0, Random: 4, Greedy: 110
# Episode: 169, Score: 187.0, Random: 4, Greedy: 130
# Episode: 170, Score: 137.0, Random: 5, Greedy: 101
# Episode: 171, Score: 144.0, Random: 6, Greedy: 107
# Episode: 172, Score: 114.0, Random: 6, Greedy: 80
# Episode: 173, Score: 110.0, Random: 5, Greedy: 73
# Episode: 174, Score: 131.0, Random: 8, Greedy: 92
# Episode: 175, Score: 143.0, Random: 7, Greedy: 97
# Episode: 176, Score: 142.0, Random: 4, Greedy: 103
# Episode: 177, Score: 122.0, Random: 9, Greedy: 87
# Episode: 178, Score: 159.0, Random: 4, Greedy: 116
# Episode: 179, Score: 179.0, Random: 7, Greedy: 123
# Episode: 180, Score: 134.0, Random: 6, Greedy: 91
# Episode: 181, Score: 140.0, Random: 6, Greedy: 99
# Episode: 182, Score: 191.0, Random: 6, Greedy: 135
# Episode: 183, Score: 163.0, Random: 8, Greedy: 111
# Episode: 184, Score: 158.0, Random: 4, Greedy: 119
# Episode: 185, Score: 164.0, Random: 4, Greedy: 123
# Episode: 186, Score: 189.0, Random: 6, Greedy: 139
# Episode: 187, Score: 178.0, Random: 12, Greedy: 119
# Episode: 188, Score: 226.0, Random: 14, Greedy: 155
# Episode: 189, Score: 194.0, Random: 8, Greedy: 139
# Episode: 190, Score: 167.0, Random: 14, Greedy: 115
# Episode: 191, Score: 217.0, Random: 4, Greedy: 158
# Episode: 192, Score: 228.0, Random: 7, Greedy: 162
# Episode: 193, Score: 151.0, Random: 8, Greedy: 111
# Episode: 194, Score: 169.0, Random: 10, Greedy: 125
# Episode: 195, Score: 210.0, Random: 8, Greedy: 146
# Episode: 196, Score: 164.0, Random: 9, Greedy: 115
# Episode: 197, Score: 166.0, Random: 5, Greedy: 115
# Episode: 198, Score: 179.0, Random: 5, Greedy: 130
# Episode: 199, Score: 168.0, Random: 6, Greedy: 123
# Episode: 200, Score: 196.0, Random: 7, Greedy: 141
# Episode: 201, Score: 212.0, Random: 7, Greedy: 155
# Episode: 202, Score: 219.0, Random: 8, Greedy: 150
# Episode: 203, Score: 183.0, Random: 5, Greedy: 134
# Episode: 204, Score: 160.0, Random: 1, Greedy: 124
# Episode: 205, Score: 210.0, Random: 6, Greedy: 155
# Episode: 206, Score: 184.0, Random: 8, Greedy: 136
# Episode: 207, Score: 176.0, Random: 8, Greedy: 117
# Episode: 208, Score: 138.0, Random: 7, Greedy: 98
# Episode: 209, Score: 158.0, Random: 11, Greedy: 106
# Episode: 210, Score: 210.0, Random: 9, Greedy: 148
# Episode: 211, Score: 157.0, Random: 7, Greedy: 112
# Episode: 212, Score: 170.0, Random: 4, Greedy: 126
# Episode: 213, Score: 144.0, Random: 8, Greedy: 101
# Episode: 214, Score: 167.0, Random: 8, Greedy: 120
# Episode: 215, Score: 151.0, Random: 8, Greedy: 106
# Episode: 216, Score: 179.0, Random: 5, Greedy: 124
# Episode: 217, Score: 204.0, Random: 8, Greedy: 142
# Episode: 218, Score: 155.0, Random: 12, Greedy: 112
# Episode: 219, Score: 180.0, Random: 6, Greedy: 126
# Episode: 220, Score: 144.0, Random: 7, Greedy: 98
# Episode: 221, Score: 180.0, Random: 3, Greedy: 132
# Episode: 222, Score: 194.0, Random: 9, Greedy: 138
# Episode: 223, Score: 181.0, Random: 12, Greedy: 127
# Episode: 224, Score: 165.0, Random: 4, Greedy: 127
# Episode: 225, Score: 160.0, Random: 9, Greedy: 110
# Episode: 226, Score: 158.0, Random: 6, Greedy: 112
# Episode: 227, Score: 375.0, Random: 17, Greedy: 259
# Episode: 228, Score: 192.0, Random: 8, Greedy: 134
# Episode: 229, Score: 173.0, Random: 6, Greedy: 124
# Episode: 230, Score: 194.0, Random: 9, Greedy: 136
# Episode: 231, Score: 181.0, Random: 3, Greedy: 138
# Episode: 232, Score: 275.0, Random: 8, Greedy: 204
# Episode: 233, Score: 313.0, Random: 8, Greedy: 227
# Episode: 234, Score: 243.0, Random: 5, Greedy: 173
# Episode: 235, Score: 248.0, Random: 7, Greedy: 185
# Episode: 236, Score: 222.0, Random: 7, Greedy: 166
# Episode: 237, Score: 211.0, Random: 11, Greedy: 149
# Episode: 238, Score: 156.0, Random: 4, Greedy: 105
# Episode: 239, Score: 177.0, Random: 10, Greedy: 123
# Episode: 240, Score: 178.0, Random: 5, Greedy: 130
# Episode: 241, Score: 276.0, Random: 12, Greedy: 194
# Episode: 242, Score: 402.0, Random: 16, Greedy: 277
# Episode: 243, Score: 310.0, Random: 7, Greedy: 218
# Episode: 244, Score: 281.0, Random: 10, Greedy: 198
# Episode: 245, Score: 187.0, Random: 10, Greedy: 128
# Episode: 246, Score: 247.0, Random: 7, Greedy: 173
# Episode: 247, Score: 424.0, Random: 14, Greedy: 306
# Episode: 248, Score: 438.0, Random: 11, Greedy: 310
# Episode: 249, Score: 277.0, Random: 14, Greedy: 201
# Episode: 250, Score: 311.0, Random: 13, Greedy: 217
# Episode: 251, Score: 334.0, Random: 9, Greedy: 233
# Episode: 252, Score: 228.0, Random: 8, Greedy: 153
# Episode: 253, Score: 373.0, Random: 20, Greedy: 270
# Episode: 254, Score: 500.0, Random: 18, Greedy: 364
# Episode: 255, Score: 469.0, Random: 18, Greedy: 328
# Episode: 256, Score: 500.0, Random: 23, Greedy: 352
# Episode: 257, Score: 500.0, Random: 19, Greedy: 363
# Episode: 258, Score: 500.0, Random: 15, Greedy: 363
# Episode: 259, Score: 500.0, Random: 12, Greedy: 376
# Episode: 260, Score: 500.0, Random: 17, Greedy: 345
# Episode: 261, Score: 500.0, Random: 8, Greedy: 374
# Episode: 262, Score: 500.0, Random: 19, Greedy: 350
# Episode: 263, Score: 500.0, Random: 18, Greedy: 358
# Episode: 264, Score: 500.0, Random: 20, Greedy: 357
# Episode: 265, Score: 500.0, Random: 13, Greedy: 352
# Episode: 266, Score: 500.0, Random: 21, Greedy: 354
# Episode: 267, Score: 500.0, Random: 18, Greedy: 366
# Episode: 268, Score: 500.0, Random: 12, Greedy: 365
# Episode: 269, Score: 500.0, Random: 18, Greedy: 342
# Episode: 270, Score: 500.0, Random: 13, Greedy: 356
# Episode: 271, Score: 500.0, Random: 13, Greedy: 369
# Episode: 272, Score: 500.0, Random: 20, Greedy: 353
# Episode: 273, Score: 500.0, Random: 18, Greedy: 357
# Episode: 274, Score: 500.0, Random: 20, Greedy: 353
# Episode: 275, Score: 500.0, Random: 22, Greedy: 347
# Episode: 276, Score: 500.0, Random: 21, Greedy: 357
# Episode: 277, Score: 500.0, Random: 15, Greedy: 373
# Episode: 278, Score: 500.0, Random: 19, Greedy: 367
# Episode: 279, Score: 500.0, Random: 20, Greedy: 346
# Episode: 280, Score: 500.0, Random: 13, Greedy: 360
# Episode: 281, Score: 500.0, Random: 24, Greedy: 357
# Episode: 282, Score: 500.0, Random: 20, Greedy: 352
# Episode: 283, Score: 500.0, Random: 19, Greedy: 359
# Episode: 284, Score: 500.0, Random: 21, Greedy: 373
# Episode: 285, Score: 500.0, Random: 19, Greedy: 360
# Episode: 286, Score: 500.0, Random: 18, Greedy: 359
# Episode: 287, Score: 500.0, Random: 20, Greedy: 358
# Episode: 288, Score: 500.0, Random: 18, Greedy: 363
# Episode: 289, Score: 500.0, Random: 15, Greedy: 360
# Episode: 290, Score: 500.0, Random: 23, Greedy: 361
# Episode: 291, Score: 500.0, Random: 20, Greedy: 359
# Episode: 292, Score: 500.0, Random: 16, Greedy: 355
# Episode: 293, Score: 500.0, Random: 19, Greedy: 363
# Episode: 294, Score: 500.0, Random: 19, Greedy: 370
# Episode: 295, Score: 500.0, Random: 22, Greedy: 350
# Episode: 296, Score: 500.0, Random: 16, Greedy: 373
# Episode: 297, Score: 500.0, Random: 22, Greedy: 350
# Episode: 298, Score: 500.0, Random: 21, Greedy: 356
# Episode: 299, Score: 357.0, Random: 14, Greedy: 263
# Episode: 300, Score: 500.0, Random: 20, Greedy: 348
# Episode: 301, Score: 500.0, Random: 22, Greedy: 363
# Episode: 302, Score: 434.0, Random: 16, Greedy: 311
# Episode: 303, Score: 500.0, Random: 16, Greedy: 362
# Episode: 304, Score: 500.0, Random: 19, Greedy: 363
# Episode: 305, Score: 500.0, Random: 19, Greedy: 349
# Episode: 306, Score: 500.0, Random: 16, Greedy: 348
# Episode: 307, Score: 500.0, Random: 16, Greedy: 367
# Episode: 308, Score: 500.0, Random: 23, Greedy: 349
# Episode: 309, Score: 500.0, Random: 17, Greedy: 352
# Episode: 310, Score: 500.0, Random: 22, Greedy: 345
# Episode: 311, Score: 500.0, Random: 26, Greedy: 357
# Episode: 312, Score: 500.0, Random: 19, Greedy: 361
# Episode: 313, Score: 253.0, Random: 11, Greedy: 181
# Episode: 314, Score: 500.0, Random: 27, Greedy: 337
# Episode: 315, Score: 500.0, Random: 27, Greedy: 356
# Episode: 316, Score: 500.0, Random: 19, Greedy: 348
# Episode: 317, Score: 500.0, Random: 14, Greedy: 370
# Episode: 318, Score: 500.0, Random: 19, Greedy: 361
# Episode: 319, Score: 500.0, Random: 9, Greedy: 373
# Episode: 320, Score: 500.0, Random: 13, Greedy: 357
# Episode: 321, Score: 500.0, Random: 21, Greedy: 359
# Episode: 322, Score: 237.0, Random: 10, Greedy: 164
# Episode: 323, Score: 46.0, Random: 4, Greedy: 32
# Episode: 324, Score: 500.0, Random: 18, Greedy: 357
# Episode: 325, Score: 500.0, Random: 17, Greedy: 355
# Episode: 326, Score: 500.0, Random: 18, Greedy: 351
# Episode: 327, Score: 500.0, Random: 17, Greedy: 336
# Episode: 328, Score: 500.0, Random: 26, Greedy: 350
# Episode: 329, Score: 500.0, Random: 21, Greedy: 357
# Episode: 330, Score: 500.0, Random: 18, Greedy: 359
# Episode: 331, Score: 500.0, Random: 28, Greedy: 345
# Episode: 332, Score: 500.0, Random: 11, Greedy: 354
# Episode: 333, Score: 500.0, Random: 19, Greedy: 345
# Episode: 334, Score: 500.0, Random: 16, Greedy: 374
# Episode: 335, Score: 500.0, Random: 11, Greedy: 348
# Episode: 336, Score: 425.0, Random: 23, Greedy: 296
# Episode: 337, Score: 500.0, Random: 13, Greedy: 360
# Episode: 338, Score: 490.0, Random: 21, Greedy: 345
# Episode: 339, Score: 500.0, Random: 18, Greedy: 358
# Episode: 340, Score: 500.0, Random: 21, Greedy: 361
# Episode: 341, Score: 500.0, Random: 16, Greedy: 365
# Episode: 342, Score: 500.0, Random: 22, Greedy: 357
# Episode: 343, Score: 500.0, Random: 27, Greedy: 344
# Episode: 344, Score: 500.0, Random: 18, Greedy: 359
# Episode: 345, Score: 500.0, Random: 15, Greedy: 355
# Episode: 346, Score: 219.0, Random: 8, Greedy: 156
# Episode: 347, Score: 500.0, Random: 23, Greedy: 351
# Episode: 348, Score: 500.0, Random: 17, Greedy: 360
# Episode: 349, Score: 500.0, Random: 21, Greedy: 368
# Episode: 350, Score: 500.0, Random: 15, Greedy: 360
# Episode: 351, Score: 500.0, Random: 10, Greedy: 373
# Episode: 352, Score: 500.0, Random: 17, Greedy: 349
# Episode: 353, Score: 500.0, Random: 22, Greedy: 337
# Episode: 354, Score: 187.0, Random: 7, Greedy: 129
# Episode: 355, Score: 500.0, Random: 20, Greedy: 355
# Episode: 356, Score: 500.0, Random: 28, Greedy: 352
# Episode: 357, Score: 500.0, Random: 17, Greedy: 360
# Episode: 358, Score: 500.0, Random: 18, Greedy: 357
# Episode: 359, Score: 500.0, Random: 19, Greedy: 362
# Episode: 360, Score: 500.0, Random: 19, Greedy: 346
# Episode: 361, Score: 500.0, Random: 21, Greedy: 363
# Episode: 362, Score: 500.0, Random: 17, Greedy: 367
# Episode: 363, Score: 500.0, Random: 21, Greedy: 359
# Episode: 364, Score: 500.0, Random: 19, Greedy: 361
# Episode: 365, Score: 500.0, Random: 12, Greedy: 361
# Episode: 366, Score: 500.0, Random: 23, Greedy: 342
# Episode: 367, Score: 500.0, Random: 12, Greedy: 356
# Episode: 368, Score: 500.0, Random: 30, Greedy: 355
# Episode: 369, Score: 500.0, Random: 17, Greedy: 361
# Episode: 370, Score: 500.0, Random: 18, Greedy: 357
# Episode: 371, Score: 500.0, Random: 20, Greedy: 363
# Episode: 372, Score: 500.0, Random: 19, Greedy: 353
# Episode: 373, Score: 500.0, Random: 18, Greedy: 368
# Episode: 374, Score: 500.0, Random: 23, Greedy: 359
# Episode: 375, Score: 500.0, Random: 13, Greedy: 358
# Episode: 376, Score: 500.0, Random: 19, Greedy: 362
# Episode: 377, Score: 500.0, Random: 23, Greedy: 348
# Episode: 378, Score: 500.0, Random: 19, Greedy: 364
# Episode: 379, Score: 105.0, Random: 6, Greedy: 74
# Episode: 380, Score: 500.0, Random: 13, Greedy: 357
# Episode: 381, Score: 500.0, Random: 15, Greedy: 363
# Episode: 382, Score: 500.0, Random: 19, Greedy: 369
# Episode: 383, Score: 500.0, Random: 20, Greedy: 354
# Episode: 384, Score: 500.0, Random: 18, Greedy: 359
# Episode: 385, Score: 500.0, Random: 10, Greedy: 371
# Episode: 386, Score: 319.0, Random: 18, Greedy: 220
# Episode: 387, Score: 500.0, Random: 18, Greedy: 372
# Episode: 388, Score: 500.0, Random: 15, Greedy: 370
# Episode: 389, Score: 500.0, Random: 23, Greedy: 350
# Episode: 390, Score: 500.0, Random: 21, Greedy: 363
# Episode: 391, Score: 500.0, Random: 12, Greedy: 371
# Episode: 392, Score: 500.0, Random: 21, Greedy: 350
# Episode: 393, Score: 500.0, Random: 13, Greedy: 364
# Episode: 394, Score: 500.0, Random: 21, Greedy: 352
# Episode: 395, Score: 500.0, Random: 23, Greedy: 365
# Episode: 396, Score: 500.0, Random: 13, Greedy: 369
# Episode: 397, Score: 500.0, Random: 27, Greedy: 342
# Episode: 398, Score: 500.0, Random: 15, Greedy: 368
# Episode: 399, Score: 500.0, Random: 19, Greedy: 349
# Episode: 400, Score: 500.0, Random: 15, Greedy: 374
# Episode: 401, Score: 500.0, Random: 21, Greedy: 354
# Episode: 402, Score: 500.0, Random: 23, Greedy: 357
# Episode: 403, Score: 500.0, Random: 18, Greedy: 358
# Episode: 404, Score: 500.0, Random: 16, Greedy: 358
# Episode: 405, Score: 500.0, Random: 16, Greedy: 352
# Episode: 406, Score: 500.0, Random: 16, Greedy: 349
# Episode: 407, Score: 419.0, Random: 18, Greedy: 300
# Episode: 408, Score: 500.0, Random: 19, Greedy: 353
# Episode: 409, Score: 500.0, Random: 17, Greedy: 356
# Episode: 410, Score: 493.0, Random: 22, Greedy: 347
# Episode: 411, Score: 500.0, Random: 15, Greedy: 362
# Episode: 412, Score: 500.0, Random: 20, Greedy: 353
# Episode: 413, Score: 500.0, Random: 15, Greedy: 366
# Episode: 414, Score: 500.0, Random: 10, Greedy: 364
# Episode: 415, Score: 500.0, Random: 22, Greedy: 349
# Episode: 416, Score: 500.0, Random: 15, Greedy: 366
# Episode: 417, Score: 500.0, Random: 16, Greedy: 362
# Episode: 418, Score: 500.0, Random: 22, Greedy: 360
# Episode: 419, Score: 500.0, Random: 22, Greedy: 356
# Episode: 420, Score: 500.0, Random: 24, Greedy: 352
# Episode: 421, Score: 500.0, Random: 16, Greedy: 361
# Episode: 422, Score: 500.0, Random: 10, Greedy: 370
# Episode: 423, Score: 500.0, Random: 14, Greedy: 362
# Episode: 424, Score: 500.0, Random: 26, Greedy: 346
# Episode: 425, Score: 500.0, Random: 23, Greedy: 363
# Episode: 426, Score: 500.0, Random: 15, Greedy: 370
# Episode: 427, Score: 143.0, Random: 5, Greedy: 101
# Episode: 428, Score: 500.0, Random: 25, Greedy: 355
# Episode: 429, Score: 500.0, Random: 16, Greedy: 352
# Episode: 430, Score: 500.0, Random: 22, Greedy: 348
# Episode: 431, Score: 500.0, Random: 14, Greedy: 366
# Episode: 432, Score: 166.0, Random: 8, Greedy: 107
# Episode: 433, Score: 500.0, Random: 11, Greedy: 360
# Episode: 434, Score: 500.0, Random: 22, Greedy: 343
# Episode: 435, Score: 500.0, Random: 14, Greedy: 359
# Episode: 436, Score: 500.0, Random: 16, Greedy: 373
# Episode: 437, Score: 500.0, Random: 18, Greedy: 358
# Episode: 438, Score: 500.0, Random: 19, Greedy: 354
# Episode: 439, Score: 500.0, Random: 13, Greedy: 359
# Episode: 440, Score: 500.0, Random: 16, Greedy: 346
# Episode: 441, Score: 500.0, Random: 19, Greedy: 352
# Episode: 442, Score: 500.0, Random: 20, Greedy: 347
# Episode: 443, Score: 500.0, Random: 27, Greedy: 346
# Episode: 444, Score: 500.0, Random: 18, Greedy: 359
# Episode: 445, Score: 500.0, Random: 13, Greedy: 355
# Episode: 446, Score: 500.0, Random: 19, Greedy: 354
# Episode: 447, Score: 500.0, Random: 20, Greedy: 364
# Episode: 448, Score: 500.0, Random: 14, Greedy: 358
# Episode: 449, Score: 500.0, Random: 17, Greedy: 359
# Episode: 450, Score: 500.0, Random: 18, Greedy: 358
# Episode: 451, Score: 500.0, Random: 13, Greedy: 354
# Episode: 452, Score: 500.0, Random: 11, Greedy: 361
# Episode: 453, Score: 500.0, Random: 13, Greedy: 351
# Episode: 454, Score: 500.0, Random: 16, Greedy: 376
# Episode: 455, Score: 500.0, Random: 18, Greedy: 355
# Episode: 456, Score: 494.0, Random: 20, Greedy: 343
# Episode: 457, Score: 500.0, Random: 20, Greedy: 351
# Episode: 458, Score: 339.0, Random: 16, Greedy: 244
# Episode: 459, Score: 185.0, Random: 6, Greedy: 125
# Episode: 460, Score: 500.0, Random: 19, Greedy: 356
# Episode: 461, Score: 500.0, Random: 21, Greedy: 360
# Episode: 462, Score: 500.0, Random: 15, Greedy: 367
# Episode: 463, Score: 500.0, Random: 22, Greedy: 349
# Episode: 464, Score: 500.0, Random: 13, Greedy: 371
# Episode: 465, Score: 205.0, Random: 7, Greedy: 144
# Episode: 466, Score: 500.0, Random: 19, Greedy: 351
# Episode: 467, Score: 500.0, Random: 19, Greedy: 352
# Episode: 468, Score: 500.0, Random: 12, Greedy: 367
# Episode: 469, Score: 500.0, Random: 15, Greedy: 360
# Episode: 470, Score: 500.0, Random: 15, Greedy: 346
# Episode: 471, Score: 472.0, Random: 23, Greedy: 336
# Episode: 472, Score: 44.0, Random: 2, Greedy: 31
# Episode: 473, Score: 500.0, Random: 19, Greedy: 359
# Episode: 474, Score: 500.0, Random: 18, Greedy: 361
# Episode: 475, Score: 500.0, Random: 16, Greedy: 361
# Episode: 476, Score: 500.0, Random: 19, Greedy: 344
# Episode: 477, Score: 500.0, Random: 18, Greedy: 348
# Episode: 478, Score: 500.0, Random: 16, Greedy: 365
# Episode: 479, Score: 500.0, Random: 19, Greedy: 358
# Episode: 480, Score: 500.0, Random: 21, Greedy: 349
# Episode: 481, Score: 500.0, Random: 11, Greedy: 367
# Episode: 482, Score: 500.0, Random: 16, Greedy: 362
# Episode: 483, Score: 500.0, Random: 23, Greedy: 361
# Episode: 484, Score: 500.0, Random: 17, Greedy: 361
# Episode: 485, Score: 500.0, Random: 27, Greedy: 344
# Episode: 486, Score: 500.0, Random: 16, Greedy: 359
# Episode: 487, Score: 500.0, Random: 11, Greedy: 363
# Episode: 488, Score: 500.0, Random: 17, Greedy: 351
# Episode: 489, Score: 500.0, Random: 9, Greedy: 357
# Episode: 490, Score: 466.0, Random: 20, Greedy: 337
# Episode: 491, Score: 270.0, Random: 6, Greedy: 187
# Episode: 492, Score: 500.0, Random: 23, Greedy: 357
# Episode: 493, Score: 239.0, Random: 13, Greedy: 163
# Episode: 494, Score: 232.0, Random: 14, Greedy: 169
# Episode: 495, Score: 500.0, Random: 20, Greedy: 350
# Episode: 496, Score: 224.0, Random: 7, Greedy: 164
# Episode: 497, Score: 500.0, Random: 15, Greedy: 361
# Episode: 498, Score: 293.0, Random: 11, Greedy: 208
# Episode: 499, Score: 500.0, Random: 10, Greedy: 366

# %%
rewards_test = []
for episode in range(10):
  obs1_val, info_val = env.reset()
  completed, term_val, trunc_val = False, False, False
  score, greedy_count, random_count = 0, 0, 0

  while not completed:
    action_val, action_type = policy_learnt(obs1_val)
    if action_type == 'greedy':
      greedy_count += 1
    else:
      random_count += 1
  
    obs2_val, reward_val, term_val, trunc_val, info_val = env.step(action_val)
    score += reward_val

    completed = term_val or trunc_val

    obs1_val = obs2_val

    if completed:
      print(f'Episode: {episode}, Score: {score}, Random: {random_count}, Greedy: {greedy_count}')
      rewards_test.append(score)
      break
# Out:
# Episode: 0, Score: 500.0, Random: 0, Greedy: 500
# Episode: 1, Score: 500.0, Random: 0, Greedy: 500
# Episode: 2, Score: 500.0, Random: 0, Greedy: 500
# Episode: 3, Score: 500.0, Random: 0, Greedy: 500
# Episode: 4, Score: 500.0, Random: 0, Greedy: 500
# Episode: 5, Score: 500.0, Random: 0, Greedy: 500
# Episode: 6, Score: 500.0, Random: 0, Greedy: 500
# Episode: 7, Score: 500.0, Random: 0, Greedy: 500
# Episode: 8, Score: 500.0, Random: 0, Greedy: 500
# Episode: 9, Score: 500.0, Random: 0, Greedy: 500

# %%
torch.save(nn_first.state_dict(), 'dqn_modified_env_weights.pth')

# %%
import matplotlib.pyplot as plt

def plot_reward(reward):
  plt.plot(reward, label='Reward')
  plt.xlabel('Episode')
  plt.ylabel('Reward Value')
  plt.title('Rewards Per Episode')
  plt.grid()
  plt.legend()
  plt.show()

plot_reward(rewards)
plot_reward(rewards_test)

# %%
import pickle
with open('dqn_modified_env_train.pkl', 'wb') as file:
  pickle.dump(rewards, file)

with open('dqn_modified_env_test.pkl', 'wb') as file:
  pickle.dump(rewards_test, file)
