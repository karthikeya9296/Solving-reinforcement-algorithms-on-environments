# %% [markdown]
# #DDQN Noise Cart Pole Environment

# %%
# !pip install gymnasium
# !pip3 install gymnasium[classic_control]

import gymnasium as gym
import torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gymnasium[classic_control]
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (1.22.4)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (4.5.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic_control]) (2.2.1)
# Collecting jax-jumpy>=1.0.0
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Collecting pygame==2.1.3
#   Downloading pygame-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 21.5 MB/s eta 0:00:00
# Installing collected packages: farama-notifications, pygame, jax-jumpy, gymnasium
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.3.0
#     Uninstalling pygame-2.3.0:
#       Successfully uninstalled pygame-2.3.0
# Successfully installed farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 pygame-2.1.3

# %%
# Wind noise function
def wind_noise(action):
    wind_direction = np.random.randint(0, 3)
    double_action = False
    
    if wind_direction == 0:  # no wind
        wind_action = action
    
    # Wind blows in the left direction and left action is taken
    elif wind_direction == 1 and action == 0:
            wind_action = 0  # left action
            double_action = True
    
    # Wind blows in the right direction and right action is taken
    elif wind_direction == 2 and action == 1:
            wind_action = 1  # Right action
            double_action = True
            
    else:
        wind_action = action # no wind_action

    return double_action, wind_action

# Modified environment step function 
def modified_env_step(environment, action):
    # Check action caused by wind
    double_action, wind_action = wind_noise(action)

    # Take steps
    if not double_action:
        observation, reward, terminated, truncated, info = environment.step(wind_action)
    else:
        observation, reward1, terminated, truncated, info = environment.step(action)
        if (terminated or truncated):
            reward = reward1
        else:
            observation, reward2, terminated, truncated, info = environment.step(wind_action)
            reward = reward1 + reward2

    return observation, reward, terminated, truncated, info

# %%
env = gym.make('CartPole-v1')

obs, info = env.reset()

obs_space = env.observation_space.shape[0]
action_space = env.action_space.n

obs, info, obs_space, action_space
# Out:
# (array([ 0.04786813,  0.04486193,  0.03970097, -0.02934268], dtype=float32),
#  {},
#  4,
#  2)

# %%
class DDQNnn(torch.nn.Module):
    def __init__(self) -> None:
        super().__init__()
        self.linear_relu_stack = torch.nn.Sequential(
            torch.nn.Linear(obs_space, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, action_space)
        )
    def forward(self, x):
        return self.linear_relu_stack(x)

nn_first = DDQNnn()
nn_second = DDQNnn()
dict_load = nn_first.state_dict()
nn_second.load_state_dict(dict_load)

nn_first, nn_second
# Out:
# (DDQNnn(
#    (linear_relu_stack): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#      (4): Linear(in_features=256, out_features=2, bias=True)
#    )
#  ),
#  DDQNnn(
#    (linear_relu_stack): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#      (4): Linear(in_features=256, out_features=2, bias=True)
#    )
#  ))

# %%
import random
import numpy as np

from collections import deque
buffer_memory = deque(maxlen = 10000)

def policy_cal(obs):
  random_val = random.random()
  epsilon_val = epsilon_cal()
  if random_val > epsilon_val:
    action_type = 'greedy'
    obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
    action_val = nn_first(obs_tensor).detach().numpy()
    action_val = np.argmax(action_val)
    return action_val, action_type
  else:
    action_type = 'random'
    action_val = env.action_space.sample()
    return action_val, action_type

def policy_learnt(obs):
  action_type = 'greedy'
  obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
  action_val = nn_first(obs_tensor).detach().numpy()
  action_val = np.argmax(action_val)
  return action_val, action_type

import math
epsilon_steps = 0
def epsilon_cal():
  diff_val = 1.0 - 0.05
  global epsilon_steps
  exp_val = math.exp(-1.0 * epsilon_steps / 1000)
  epsilon_steps += 1
  epsilon_val = 0.05 + diff_val * exp_val
  return epsilon_val

optimizer_param = nn_first.parameters()
optimizer = torch.optim.AdamW(optimizer_param, lr=1e-4, amsgrad=True)

# %%
def experience_cal():
  if len(buffer_memory) < 128:
    return
  
  buffer_batch = random.sample(buffer_memory, 128)
  batch_obs1, batch_obs2 = [], []
  batch_reward, batch_action = [], []
  batch_completed = []

  for val in buffer_batch:
    obs1_val, obs2_val, reward_val, action_val, completed_val = val
    batch_completed.append(completed_val)
    batch_obs1.append(obs1_val)
    batch_obs2.append(obs2_val)
    batch_action.append([action_val])
    batch_reward.append(reward_val)    
  
  batch_obs2_nf = []
  for i in range(len(batch_completed)):
    if batch_completed[i]:
      batch_obs2_nf.append(batch_obs2[i])
  
  batch_completed = torch.tensor(batch_completed, dtype=torch.bool) # 128
  batch_obs1 = torch.tensor(batch_obs1) # 128
  batch_obs2 = torch.tensor(batch_obs2) # 128
  batch_obs2_nf = torch.tensor(batch_obs2_nf) # < 128
  batch_action = torch.tensor(batch_action, dtype=torch.int64) # 128
  batch_reward = torch.tensor(batch_reward) # 128
  
  obs1_qval = nn_first(batch_obs1).gather(1, batch_action)
  obs2_qval = nn_second(batch_obs1).gather(1, batch_action)

  batch_obs2_val = torch.zeros(128)
  with torch.set_grad_enabled(False):
    max_val_list = nn_second(batch_obs2_nf).detach()
    max_val = max_val_list.max(1)[0]
    batch_obs2_val[batch_completed] = max_val

  discounted_reward = 0.99 * batch_obs2_val
  obs2_qval = batch_reward + discounted_reward
  
  loss_function = torch.nn.MSELoss()
  criterion = loss_function
  loss_param1 = obs1_qval
  loss_param2 = obs2_qval[:, None]
  loss = criterion(loss_param1, loss_param2)

  optimizer.zero_grad()
  loss.backward()
  
  grad_max_val = 100
  grad_model_param = nn_first.parameters()
  torch.nn.utils.clip_grad_value_(grad_model_param, grad_max_val)
  
  optimizer.step()

  update_cf1 = 0.005
  update_cf2 = 1 - 0.005
  nn_first_dict = nn_first.state_dict()
  nn_second_dict = nn_second.state_dict()
  for dict_key in nn_first.state_dict():
    nn_first_update = update_cf1 * nn_first_dict[dict_key]
    nn_second_update = update_cf2 * nn_second_dict[dict_key]
    update_val = nn_first_update + nn_second_update
    nn_second_dict[dict_key] = update_val
  nn_second.load_state_dict(nn_second_dict)

# %%
rewards = []
for episode in range(500):
  obs1_val, info_val = env.reset()
  completed, term_val, trunc_val = False, False, False
  score, greedy_count, random_count = 0, 0, 0

  while not completed:
    action_val, action_type = policy_cal(obs1_val)
    if action_type == 'greedy':
      greedy_count += 1
    else:
      random_count += 1
  
    # modified_env_step function
    obs2_val, reward_val, term_val, trunc_val, info_val = modified_env_step(env, action_val)
    score += reward_val

    completed = term_val or trunc_val
    completed_val = not completed

    experience = (obs1_val, obs2_val, reward_val, action_val, completed_val)
    buffer_memory.append(experience)
    obs1_val = obs2_val

    experience_cal()

    if completed:
      print(f'Episode: {episode}, Score: {score}, Random: {random_count}, Greedy: {greedy_count}')
      rewards.append(score)
      break
# Out:
# Episode: 0, Score: 37.0, Random: 26, Greedy: 0
# Episode: 1, Score: 12.0, Random: 8, Greedy: 0
# Episode: 2, Score: 20.0, Random: 15, Greedy: 0
# Episode: 3, Score: 22.0, Random: 18, Greedy: 1
# Episode: 4, Score: 21.0, Random: 10, Greedy: 4
# Episode: 5, Score: 14.0, Random: 11, Greedy: 1
# Episode: 6, Score: 14.0, Random: 9, Greedy: 2
# Episode: 7, Score: 16.0, Random: 8, Greedy: 3
# Episode: 8, Score: 18.0, Random: 12, Greedy: 1
# <ipython-input-6-f342ea3213c3>:24: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   batch_obs1 = torch.tensor(batch_obs1) # 128
# Episode: 9, Score: 18.0, Random: 9, Greedy: 3
# Episode: 10, Score: 25.0, Random: 16, Greedy: 6
# Episode: 11, Score: 19.0, Random: 15, Greedy: 2
# Episode: 12, Score: 16.0, Random: 12, Greedy: 2
# Episode: 13, Score: 11.0, Random: 8, Greedy: 1
# Episode: 14, Score: 18.0, Random: 12, Greedy: 2
# Episode: 15, Score: 22.0, Random: 10, Greedy: 7
# Episode: 16, Score: 20.0, Random: 11, Greedy: 4
# Episode: 17, Score: 9.0, Random: 3, Greedy: 4
# Episode: 18, Score: 15.0, Random: 11, Greedy: 0
# Episode: 19, Score: 12.0, Random: 9, Greedy: 2
# Episode: 20, Score: 10.0, Random: 5, Greedy: 2
# Episode: 21, Score: 20.0, Random: 13, Greedy: 3
# Episode: 22, Score: 10.0, Random: 5, Greedy: 3
# Episode: 23, Score: 19.0, Random: 11, Greedy: 2
# Episode: 24, Score: 17.0, Random: 10, Greedy: 4
# Episode: 25, Score: 11.0, Random: 6, Greedy: 2
# Episode: 26, Score: 15.0, Random: 12, Greedy: 1
# Episode: 27, Score: 18.0, Random: 10, Greedy: 2
# Episode: 28, Score: 9.0, Random: 5, Greedy: 1
# Episode: 29, Score: 9.0, Random: 4, Greedy: 3
# Episode: 30, Score: 14.0, Random: 6, Greedy: 6
# Episode: 31, Score: 9.0, Random: 6, Greedy: 1
# Episode: 32, Score: 13.0, Random: 7, Greedy: 5
# Episode: 33, Score: 16.0, Random: 9, Greedy: 3
# Episode: 34, Score: 19.0, Random: 10, Greedy: 6
# Episode: 35, Score: 42.0, Random: 21, Greedy: 10
# Episode: 36, Score: 24.0, Random: 10, Greedy: 7
# Episode: 37, Score: 11.0, Random: 6, Greedy: 3
# Episode: 38, Score: 15.0, Random: 7, Greedy: 6
# Episode: 39, Score: 11.0, Random: 4, Greedy: 4
# Episode: 40, Score: 10.0, Random: 4, Greedy: 5
# Episode: 41, Score: 18.0, Random: 9, Greedy: 3
# Episode: 42, Score: 11.0, Random: 4, Greedy: 4
# Episode: 43, Score: 12.0, Random: 6, Greedy: 4
# Episode: 44, Score: 14.0, Random: 6, Greedy: 5
# Episode: 45, Score: 13.0, Random: 6, Greedy: 3
# Episode: 46, Score: 9.0, Random: 6, Greedy: 2
# Episode: 47, Score: 14.0, Random: 6, Greedy: 4
# Episode: 48, Score: 18.0, Random: 7, Greedy: 7
# Episode: 49, Score: 11.0, Random: 4, Greedy: 2
# Episode: 50, Score: 14.0, Random: 7, Greedy: 5
# Episode: 51, Score: 12.0, Random: 5, Greedy: 4
# Episode: 52, Score: 13.0, Random: 5, Greedy: 6
# Episode: 53, Score: 17.0, Random: 10, Greedy: 4
# Episode: 54, Score: 13.0, Random: 8, Greedy: 3
# Episode: 55, Score: 25.0, Random: 11, Greedy: 9
# Episode: 56, Score: 59.0, Random: 26, Greedy: 14
# Episode: 57, Score: 9.0, Random: 4, Greedy: 3
# Episode: 58, Score: 13.0, Random: 5, Greedy: 6
# Episode: 59, Score: 29.0, Random: 14, Greedy: 8
# Episode: 60, Score: 13.0, Random: 5, Greedy: 4
# Episode: 61, Score: 11.0, Random: 4, Greedy: 3
# Episode: 62, Score: 11.0, Random: 6, Greedy: 2
# Episode: 63, Score: 12.0, Random: 4, Greedy: 5
# Episode: 64, Score: 31.0, Random: 13, Greedy: 10
# Episode: 65, Score: 14.0, Random: 6, Greedy: 5
# Episode: 66, Score: 12.0, Random: 8, Greedy: 1
# Episode: 67, Score: 40.0, Random: 11, Greedy: 18
# Episode: 68, Score: 13.0, Random: 3, Greedy: 6
# Episode: 69, Score: 66.0, Random: 19, Greedy: 33
# Episode: 70, Score: 14.0, Random: 8, Greedy: 4
# Episode: 71, Score: 47.0, Random: 10, Greedy: 22
# Episode: 72, Score: 39.0, Random: 9, Greedy: 18
# Episode: 73, Score: 69.0, Random: 13, Greedy: 35
# Episode: 74, Score: 61.0, Random: 17, Greedy: 32
# Episode: 75, Score: 54.0, Random: 17, Greedy: 24
# Episode: 76, Score: 133.0, Random: 34, Greedy: 63
# Episode: 77, Score: 66.0, Random: 18, Greedy: 36
# Episode: 78, Score: 48.0, Random: 11, Greedy: 20
# Episode: 79, Score: 69.0, Random: 9, Greedy: 41
# Episode: 80, Score: 186.0, Random: 41, Greedy: 101
# Episode: 81, Score: 47.0, Random: 7, Greedy: 27
# Episode: 82, Score: 166.0, Random: 21, Greedy: 105
# Episode: 83, Score: 123.0, Random: 22, Greedy: 71
# Episode: 84, Score: 237.0, Random: 46, Greedy: 138
# Episode: 85, Score: 219.0, Random: 31, Greedy: 135
# Episode: 86, Score: 313.0, Random: 30, Greedy: 207
# Episode: 87, Score: 314.0, Random: 28, Greedy: 218
# Episode: 88, Score: 261.0, Random: 20, Greedy: 174
# Episode: 89, Score: 225.0, Random: 19, Greedy: 149
# Episode: 90, Score: 243.0, Random: 19, Greedy: 159
# Episode: 91, Score: 266.0, Random: 14, Greedy: 181
# Episode: 92, Score: 276.0, Random: 16, Greedy: 191
# Episode: 93, Score: 411.0, Random: 22, Greedy: 293
# Episode: 94, Score: 241.0, Random: 10, Greedy: 170
# Episode: 95, Score: 245.0, Random: 10, Greedy: 173
# Episode: 96, Score: 267.0, Random: 11, Greedy: 188
# Episode: 97, Score: 226.0, Random: 10, Greedy: 161
# Episode: 98, Score: 377.0, Random: 18, Greedy: 268
# Episode: 99, Score: 256.0, Random: 5, Greedy: 190
# Episode: 100, Score: 275.0, Random: 12, Greedy: 191
# Episode: 101, Score: 252.0, Random: 9, Greedy: 182
# Episode: 102, Score: 271.0, Random: 3, Greedy: 198
# Episode: 103, Score: 226.0, Random: 9, Greedy: 164
# Episode: 104, Score: 318.0, Random: 14, Greedy: 239
# Episode: 105, Score: 296.0, Random: 14, Greedy: 207
# Episode: 106, Score: 360.0, Random: 11, Greedy: 272
# Episode: 107, Score: 295.0, Random: 6, Greedy: 221
# Episode: 108, Score: 437.0, Random: 22, Greedy: 303
# Episode: 109, Score: 224.0, Random: 6, Greedy: 171
# Episode: 110, Score: 221.0, Random: 5, Greedy: 159
# Episode: 111, Score: 263.0, Random: 7, Greedy: 189
# Episode: 112, Score: 334.0, Random: 19, Greedy: 234
# Episode: 113, Score: 216.0, Random: 6, Greedy: 161
# Episode: 114, Score: 452.0, Random: 16, Greedy: 316
# Episode: 115, Score: 258.0, Random: 6, Greedy: 198
# Episode: 116, Score: 307.0, Random: 11, Greedy: 219
# Episode: 117, Score: 293.0, Random: 11, Greedy: 202
# Episode: 118, Score: 336.0, Random: 13, Greedy: 238
# Episode: 119, Score: 229.0, Random: 4, Greedy: 165
# Episode: 120, Score: 354.0, Random: 11, Greedy: 259
# Episode: 121, Score: 335.0, Random: 11, Greedy: 238
# Episode: 122, Score: 431.0, Random: 12, Greedy: 307
# Episode: 123, Score: 363.0, Random: 14, Greedy: 254
# Episode: 124, Score: 301.0, Random: 12, Greedy: 217
# Episode: 125, Score: 279.0, Random: 10, Greedy: 188
# Episode: 126, Score: 222.0, Random: 10, Greedy: 154
# Episode: 127, Score: 365.0, Random: 11, Greedy: 266
# Episode: 128, Score: 440.0, Random: 14, Greedy: 322
# Episode: 129, Score: 397.0, Random: 18, Greedy: 282
# Episode: 130, Score: 274.0, Random: 9, Greedy: 201
# Episode: 131, Score: 250.0, Random: 9, Greedy: 186
# Episode: 132, Score: 203.0, Random: 11, Greedy: 135
# Episode: 133, Score: 287.0, Random: 13, Greedy: 204
# Episode: 134, Score: 180.0, Random: 11, Greedy: 121
# Episode: 135, Score: 351.0, Random: 18, Greedy: 248
# Episode: 136, Score: 260.0, Random: 14, Greedy: 182
# Episode: 137, Score: 226.0, Random: 10, Greedy: 166
# Episode: 138, Score: 206.0, Random: 13, Greedy: 145
# Episode: 139, Score: 344.0, Random: 10, Greedy: 252
# Episode: 140, Score: 389.0, Random: 14, Greedy: 270
# Episode: 141, Score: 212.0, Random: 9, Greedy: 151
# Episode: 142, Score: 263.0, Random: 7, Greedy: 191
# Episode: 143, Score: 206.0, Random: 8, Greedy: 139
# Episode: 144, Score: 210.0, Random: 5, Greedy: 144
# Episode: 145, Score: 381.0, Random: 15, Greedy: 276
# Episode: 146, Score: 296.0, Random: 12, Greedy: 206
# Episode: 147, Score: 500.0, Random: 28, Greedy: 335
# Episode: 148, Score: 313.0, Random: 11, Greedy: 226
# Episode: 149, Score: 373.0, Random: 10, Greedy: 265
# Episode: 150, Score: 326.0, Random: 8, Greedy: 228
# Episode: 151, Score: 282.0, Random: 8, Greedy: 202
# Episode: 152, Score: 273.0, Random: 13, Greedy: 191
# Episode: 153, Score: 288.0, Random: 7, Greedy: 208
# Episode: 154, Score: 258.0, Random: 11, Greedy: 175
# Episode: 155, Score: 293.0, Random: 12, Greedy: 203
# Episode: 156, Score: 222.0, Random: 12, Greedy: 157
# Episode: 157, Score: 260.0, Random: 7, Greedy: 187
# Episode: 158, Score: 276.0, Random: 8, Greedy: 200
# Episode: 159, Score: 292.0, Random: 11, Greedy: 200
# Episode: 160, Score: 297.0, Random: 13, Greedy: 209
# Episode: 161, Score: 223.0, Random: 6, Greedy: 166
# Episode: 162, Score: 217.0, Random: 11, Greedy: 154
# Episode: 163, Score: 266.0, Random: 11, Greedy: 176
# Episode: 164, Score: 238.0, Random: 9, Greedy: 168
# Episode: 165, Score: 201.0, Random: 8, Greedy: 148
# Episode: 166, Score: 213.0, Random: 11, Greedy: 151
# Episode: 167, Score: 183.0, Random: 5, Greedy: 135
# Episode: 168, Score: 197.0, Random: 8, Greedy: 140
# Episode: 169, Score: 344.0, Random: 12, Greedy: 244
# Episode: 170, Score: 290.0, Random: 11, Greedy: 209
# Episode: 171, Score: 260.0, Random: 7, Greedy: 186
# Episode: 172, Score: 286.0, Random: 8, Greedy: 207
# Episode: 173, Score: 255.0, Random: 12, Greedy: 179
# Episode: 174, Score: 241.0, Random: 5, Greedy: 183
# Episode: 175, Score: 238.0, Random: 12, Greedy: 160
# Episode: 176, Score: 270.0, Random: 12, Greedy: 195
# Episode: 177, Score: 213.0, Random: 11, Greedy: 152
# Episode: 178, Score: 272.0, Random: 5, Greedy: 190
# Episode: 179, Score: 211.0, Random: 9, Greedy: 147
# Episode: 180, Score: 226.0, Random: 15, Greedy: 152
# Episode: 181, Score: 289.0, Random: 16, Greedy: 199
# Episode: 182, Score: 206.0, Random: 10, Greedy: 140
# Episode: 183, Score: 316.0, Random: 8, Greedy: 234
# Episode: 184, Score: 227.0, Random: 6, Greedy: 167
# Episode: 185, Score: 255.0, Random: 8, Greedy: 184
# Episode: 186, Score: 234.0, Random: 5, Greedy: 166
# Episode: 187, Score: 208.0, Random: 4, Greedy: 150
# Episode: 188, Score: 216.0, Random: 12, Greedy: 150
# Episode: 189, Score: 372.0, Random: 12, Greedy: 266
# Episode: 190, Score: 224.0, Random: 6, Greedy: 154
# Episode: 191, Score: 367.0, Random: 15, Greedy: 266
# Episode: 192, Score: 235.0, Random: 8, Greedy: 165
# Episode: 193, Score: 406.0, Random: 14, Greedy: 284
# Episode: 194, Score: 194.0, Random: 7, Greedy: 142
# Episode: 195, Score: 204.0, Random: 12, Greedy: 144
# Episode: 196, Score: 286.0, Random: 12, Greedy: 195
# Episode: 197, Score: 240.0, Random: 7, Greedy: 174
# Episode: 198, Score: 237.0, Random: 10, Greedy: 171
# Episode: 199, Score: 189.0, Random: 7, Greedy: 135
# Episode: 200, Score: 216.0, Random: 3, Greedy: 159
# Episode: 201, Score: 196.0, Random: 11, Greedy: 133
# Episode: 202, Score: 247.0, Random: 7, Greedy: 178
# Episode: 203, Score: 202.0, Random: 6, Greedy: 146
# Episode: 204, Score: 226.0, Random: 11, Greedy: 159
# Episode: 205, Score: 252.0, Random: 8, Greedy: 177
# Episode: 206, Score: 206.0, Random: 11, Greedy: 148
# Episode: 207, Score: 243.0, Random: 5, Greedy: 177
# Episode: 208, Score: 190.0, Random: 5, Greedy: 135
# Episode: 209, Score: 233.0, Random: 9, Greedy: 165
# Episode: 210, Score: 263.0, Random: 10, Greedy: 182
# Episode: 211, Score: 238.0, Random: 10, Greedy: 172
# Episode: 212, Score: 190.0, Random: 12, Greedy: 135
# Episode: 213, Score: 275.0, Random: 14, Greedy: 192
# Episode: 214, Score: 264.0, Random: 11, Greedy: 185
# Episode: 215, Score: 204.0, Random: 5, Greedy: 152
# Episode: 216, Score: 252.0, Random: 12, Greedy: 177
# Episode: 217, Score: 199.0, Random: 5, Greedy: 141
# Episode: 218, Score: 189.0, Random: 8, Greedy: 129
# Episode: 219, Score: 247.0, Random: 9, Greedy: 172
# Episode: 220, Score: 245.0, Random: 5, Greedy: 181
# Episode: 221, Score: 290.0, Random: 11, Greedy: 207
# Episode: 222, Score: 254.0, Random: 13, Greedy: 179
# Episode: 223, Score: 238.0, Random: 3, Greedy: 170
# Episode: 224, Score: 287.0, Random: 9, Greedy: 209
# Episode: 225, Score: 272.0, Random: 9, Greedy: 191
# Episode: 226, Score: 285.0, Random: 8, Greedy: 209
# Episode: 227, Score: 280.0, Random: 10, Greedy: 200
# Episode: 228, Score: 225.0, Random: 15, Greedy: 153
# Episode: 229, Score: 213.0, Random: 7, Greedy: 148
# Episode: 230, Score: 233.0, Random: 7, Greedy: 172
# Episode: 231, Score: 215.0, Random: 8, Greedy: 159
# Episode: 232, Score: 228.0, Random: 6, Greedy: 163
# Episode: 233, Score: 229.0, Random: 7, Greedy: 172
# Episode: 234, Score: 232.0, Random: 9, Greedy: 168
# Episode: 235, Score: 279.0, Random: 7, Greedy: 198
# Episode: 236, Score: 248.0, Random: 13, Greedy: 182
# Episode: 237, Score: 229.0, Random: 7, Greedy: 160
# Episode: 238, Score: 220.0, Random: 9, Greedy: 161
# Episode: 239, Score: 227.0, Random: 6, Greedy: 161
# Episode: 240, Score: 325.0, Random: 18, Greedy: 225
# Episode: 241, Score: 246.0, Random: 11, Greedy: 168
# Episode: 242, Score: 211.0, Random: 10, Greedy: 152
# Episode: 243, Score: 257.0, Random: 9, Greedy: 182
# Episode: 244, Score: 215.0, Random: 7, Greedy: 155
# Episode: 245, Score: 236.0, Random: 7, Greedy: 169
# Episode: 246, Score: 226.0, Random: 10, Greedy: 152
# Episode: 247, Score: 261.0, Random: 7, Greedy: 186
# Episode: 248, Score: 232.0, Random: 6, Greedy: 170
# Episode: 249, Score: 217.0, Random: 5, Greedy: 163
# Episode: 250, Score: 220.0, Random: 6, Greedy: 163
# Episode: 251, Score: 331.0, Random: 15, Greedy: 227
# Episode: 252, Score: 230.0, Random: 10, Greedy: 162
# Episode: 253, Score: 232.0, Random: 13, Greedy: 167
# Episode: 254, Score: 314.0, Random: 16, Greedy: 223
# Episode: 255, Score: 235.0, Random: 8, Greedy: 164
# Episode: 256, Score: 240.0, Random: 12, Greedy: 164
# Episode: 257, Score: 373.0, Random: 18, Greedy: 263
# Episode: 258, Score: 268.0, Random: 8, Greedy: 189
# Episode: 259, Score: 248.0, Random: 7, Greedy: 177
# Episode: 260, Score: 233.0, Random: 6, Greedy: 171
# Episode: 261, Score: 256.0, Random: 10, Greedy: 182
# Episode: 262, Score: 260.0, Random: 7, Greedy: 193
# Episode: 263, Score: 275.0, Random: 12, Greedy: 197
# Episode: 264, Score: 213.0, Random: 12, Greedy: 148
# Episode: 265, Score: 253.0, Random: 8, Greedy: 182
# Episode: 266, Score: 245.0, Random: 12, Greedy: 172
# Episode: 267, Score: 225.0, Random: 9, Greedy: 156
# Episode: 268, Score: 260.0, Random: 18, Greedy: 176
# Episode: 269, Score: 259.0, Random: 10, Greedy: 183
# Episode: 270, Score: 281.0, Random: 11, Greedy: 191
# Episode: 271, Score: 233.0, Random: 9, Greedy: 161
# Episode: 272, Score: 240.0, Random: 6, Greedy: 169
# Episode: 273, Score: 226.0, Random: 13, Greedy: 151
# Episode: 274, Score: 215.0, Random: 8, Greedy: 148
# Episode: 275, Score: 269.0, Random: 10, Greedy: 191
# Episode: 276, Score: 269.0, Random: 14, Greedy: 182
# Episode: 277, Score: 283.0, Random: 12, Greedy: 200
# Episode: 278, Score: 251.0, Random: 10, Greedy: 175
# Episode: 279, Score: 250.0, Random: 5, Greedy: 188
# Episode: 280, Score: 282.0, Random: 7, Greedy: 212
# Episode: 281, Score: 249.0, Random: 7, Greedy: 188
# Episode: 282, Score: 232.0, Random: 6, Greedy: 174
# Episode: 283, Score: 230.0, Random: 10, Greedy: 165
# Episode: 284, Score: 262.0, Random: 15, Greedy: 181
# Episode: 285, Score: 245.0, Random: 7, Greedy: 186
# Episode: 286, Score: 293.0, Random: 5, Greedy: 214
# Episode: 287, Score: 280.0, Random: 10, Greedy: 196
# Episode: 288, Score: 258.0, Random: 9, Greedy: 172
# Episode: 289, Score: 301.0, Random: 16, Greedy: 211
# Episode: 290, Score: 281.0, Random: 13, Greedy: 197
# Episode: 291, Score: 243.0, Random: 10, Greedy: 169
# Episode: 292, Score: 260.0, Random: 11, Greedy: 186
# Episode: 293, Score: 244.0, Random: 11, Greedy: 179
# Episode: 294, Score: 289.0, Random: 18, Greedy: 195
# Episode: 295, Score: 280.0, Random: 11, Greedy: 201
# Episode: 296, Score: 276.0, Random: 10, Greedy: 194
# Episode: 297, Score: 286.0, Random: 8, Greedy: 207
# Episode: 298, Score: 279.0, Random: 10, Greedy: 213
# Episode: 299, Score: 286.0, Random: 15, Greedy: 201
# Episode: 300, Score: 279.0, Random: 5, Greedy: 204
# Episode: 301, Score: 292.0, Random: 12, Greedy: 220
# Episode: 302, Score: 276.0, Random: 10, Greedy: 196
# Episode: 303, Score: 260.0, Random: 9, Greedy: 184
# Episode: 304, Score: 354.0, Random: 14, Greedy: 254
# Episode: 305, Score: 301.0, Random: 9, Greedy: 214
# Episode: 306, Score: 328.0, Random: 16, Greedy: 235
# Episode: 307, Score: 295.0, Random: 10, Greedy: 202
# Episode: 308, Score: 314.0, Random: 12, Greedy: 228
# Episode: 309, Score: 328.0, Random: 10, Greedy: 231
# Episode: 310, Score: 282.0, Random: 15, Greedy: 196
# Episode: 311, Score: 312.0, Random: 17, Greedy: 218
# Episode: 312, Score: 348.0, Random: 11, Greedy: 254
# Episode: 313, Score: 329.0, Random: 10, Greedy: 243
# Episode: 314, Score: 277.0, Random: 10, Greedy: 198
# Episode: 315, Score: 418.0, Random: 18, Greedy: 289
# Episode: 316, Score: 341.0, Random: 11, Greedy: 249
# Episode: 317, Score: 343.0, Random: 8, Greedy: 254
# Episode: 318, Score: 414.0, Random: 16, Greedy: 295
# Episode: 319, Score: 424.0, Random: 15, Greedy: 300
# Episode: 320, Score: 458.0, Random: 19, Greedy: 320
# Episode: 321, Score: 432.0, Random: 10, Greedy: 312
# Episode: 322, Score: 500.0, Random: 27, Greedy: 365
# Episode: 323, Score: 500.0, Random: 15, Greedy: 380
# Episode: 324, Score: 500.0, Random: 19, Greedy: 354
# Episode: 325, Score: 500.0, Random: 19, Greedy: 358
# Episode: 326, Score: 500.0, Random: 23, Greedy: 353
# Episode: 327, Score: 500.0, Random: 11, Greedy: 364
# Episode: 328, Score: 407.0, Random: 8, Greedy: 301
# Episode: 329, Score: 333.0, Random: 9, Greedy: 245
# Episode: 330, Score: 337.0, Random: 9, Greedy: 247
# Episode: 331, Score: 491.0, Random: 23, Greedy: 335
# Episode: 332, Score: 333.0, Random: 11, Greedy: 235
# Episode: 333, Score: 269.0, Random: 5, Greedy: 195
# Episode: 334, Score: 262.0, Random: 6, Greedy: 174
# Episode: 335, Score: 319.0, Random: 3, Greedy: 229
# Episode: 336, Score: 284.0, Random: 10, Greedy: 196
# Episode: 337, Score: 283.0, Random: 12, Greedy: 194
# Episode: 338, Score: 322.0, Random: 12, Greedy: 227
# Episode: 339, Score: 345.0, Random: 10, Greedy: 249
# Episode: 340, Score: 500.0, Random: 22, Greedy: 357
# Episode: 341, Score: 500.0, Random: 22, Greedy: 350
# Episode: 342, Score: 500.0, Random: 25, Greedy: 351
# Episode: 343, Score: 500.0, Random: 14, Greedy: 363
# Episode: 344, Score: 500.0, Random: 18, Greedy: 347
# Episode: 345, Score: 500.0, Random: 18, Greedy: 365
# Episode: 346, Score: 500.0, Random: 19, Greedy: 356
# Episode: 347, Score: 500.0, Random: 16, Greedy: 364
# Episode: 348, Score: 465.0, Random: 13, Greedy: 340
# Episode: 349, Score: 500.0, Random: 17, Greedy: 362
# Episode: 350, Score: 500.0, Random: 19, Greedy: 366
# Episode: 351, Score: 500.0, Random: 22, Greedy: 357
# Episode: 352, Score: 500.0, Random: 13, Greedy: 363
# Episode: 353, Score: 500.0, Random: 20, Greedy: 358
# Episode: 354, Score: 277.0, Random: 14, Greedy: 186
# Episode: 355, Score: 294.0, Random: 13, Greedy: 216
# Episode: 356, Score: 426.0, Random: 14, Greedy: 302
# Episode: 357, Score: 469.0, Random: 15, Greedy: 336
# Episode: 358, Score: 500.0, Random: 21, Greedy: 366
# Episode: 359, Score: 415.0, Random: 23, Greedy: 287
# Episode: 360, Score: 500.0, Random: 11, Greedy: 362
# Episode: 361, Score: 500.0, Random: 22, Greedy: 349
# Episode: 362, Score: 500.0, Random: 17, Greedy: 364
# Episode: 363, Score: 500.0, Random: 12, Greedy: 355
# Episode: 364, Score: 500.0, Random: 25, Greedy: 347
# Episode: 365, Score: 500.0, Random: 20, Greedy: 354
# Episode: 366, Score: 500.0, Random: 16, Greedy: 360
# Episode: 367, Score: 500.0, Random: 19, Greedy: 350
# Episode: 368, Score: 500.0, Random: 23, Greedy: 350
# Episode: 369, Score: 500.0, Random: 14, Greedy: 349
# Episode: 370, Score: 500.0, Random: 11, Greedy: 348
# Episode: 371, Score: 500.0, Random: 20, Greedy: 374
# Episode: 372, Score: 500.0, Random: 21, Greedy: 346
# Episode: 373, Score: 500.0, Random: 15, Greedy: 361
# Episode: 374, Score: 500.0, Random: 18, Greedy: 347
# Episode: 375, Score: 500.0, Random: 26, Greedy: 338
# Episode: 376, Score: 500.0, Random: 18, Greedy: 349
# Episode: 377, Score: 500.0, Random: 25, Greedy: 344
# Episode: 378, Score: 500.0, Random: 22, Greedy: 354
# Episode: 379, Score: 500.0, Random: 20, Greedy: 354
# Episode: 380, Score: 500.0, Random: 18, Greedy: 346
# Episode: 381, Score: 500.0, Random: 17, Greedy: 363
# Episode: 382, Score: 500.0, Random: 19, Greedy: 357
# Episode: 383, Score: 500.0, Random: 13, Greedy: 370
# Episode: 384, Score: 500.0, Random: 16, Greedy: 363
# Episode: 385, Score: 500.0, Random: 20, Greedy: 347
# Episode: 386, Score: 500.0, Random: 20, Greedy: 365
# Episode: 387, Score: 500.0, Random: 20, Greedy: 358
# Episode: 388, Score: 500.0, Random: 17, Greedy: 361
# Episode: 389, Score: 500.0, Random: 17, Greedy: 353
# Episode: 390, Score: 500.0, Random: 18, Greedy: 354
# Episode: 391, Score: 500.0, Random: 27, Greedy: 347
# Episode: 392, Score: 500.0, Random: 17, Greedy: 364
# Episode: 393, Score: 500.0, Random: 17, Greedy: 367
# Episode: 394, Score: 500.0, Random: 19, Greedy: 352
# Episode: 395, Score: 500.0, Random: 21, Greedy: 350
# Episode: 396, Score: 500.0, Random: 22, Greedy: 345
# Episode: 397, Score: 500.0, Random: 20, Greedy: 357
# Episode: 398, Score: 500.0, Random: 21, Greedy: 351
# Episode: 399, Score: 500.0, Random: 20, Greedy: 350
# Episode: 400, Score: 500.0, Random: 20, Greedy: 357
# Episode: 401, Score: 500.0, Random: 18, Greedy: 365
# Episode: 402, Score: 500.0, Random: 12, Greedy: 369
# Episode: 403, Score: 500.0, Random: 22, Greedy: 350
# Episode: 404, Score: 500.0, Random: 13, Greedy: 370
# Episode: 405, Score: 500.0, Random: 13, Greedy: 358
# Episode: 406, Score: 500.0, Random: 22, Greedy: 351
# Episode: 407, Score: 500.0, Random: 16, Greedy: 343
# Episode: 408, Score: 500.0, Random: 21, Greedy: 352
# Episode: 409, Score: 500.0, Random: 24, Greedy: 352
# Episode: 410, Score: 500.0, Random: 24, Greedy: 358
# Episode: 411, Score: 500.0, Random: 23, Greedy: 348
# Episode: 412, Score: 500.0, Random: 28, Greedy: 336
# Episode: 413, Score: 500.0, Random: 26, Greedy: 351
# Episode: 414, Score: 500.0, Random: 19, Greedy: 353
# Episode: 415, Score: 500.0, Random: 25, Greedy: 352
# Episode: 416, Score: 500.0, Random: 14, Greedy: 363
# Episode: 417, Score: 500.0, Random: 18, Greedy: 358
# Episode: 418, Score: 500.0, Random: 23, Greedy: 364
# Episode: 419, Score: 500.0, Random: 22, Greedy: 361
# Episode: 420, Score: 500.0, Random: 17, Greedy: 357
# Episode: 421, Score: 500.0, Random: 22, Greedy: 363
# Episode: 422, Score: 500.0, Random: 27, Greedy: 362
# Episode: 423, Score: 500.0, Random: 18, Greedy: 359
# Episode: 424, Score: 500.0, Random: 11, Greedy: 367
# Episode: 425, Score: 500.0, Random: 14, Greedy: 361
# Episode: 426, Score: 500.0, Random: 26, Greedy: 347
# Episode: 427, Score: 500.0, Random: 21, Greedy: 341
# Episode: 428, Score: 500.0, Random: 13, Greedy: 356
# Episode: 429, Score: 500.0, Random: 22, Greedy: 342
# Episode: 430, Score: 500.0, Random: 15, Greedy: 354
# Episode: 431, Score: 500.0, Random: 16, Greedy: 364
# Episode: 432, Score: 500.0, Random: 21, Greedy: 366
# Episode: 433, Score: 500.0, Random: 19, Greedy: 360
# Episode: 434, Score: 500.0, Random: 14, Greedy: 372
# Episode: 435, Score: 500.0, Random: 18, Greedy: 355
# Episode: 436, Score: 500.0, Random: 15, Greedy: 364
# Episode: 437, Score: 473.0, Random: 14, Greedy: 332
# Episode: 438, Score: 500.0, Random: 17, Greedy: 363
# Episode: 439, Score: 500.0, Random: 6, Greedy: 370
# Episode: 440, Score: 500.0, Random: 19, Greedy: 348
# Episode: 441, Score: 500.0, Random: 16, Greedy: 361
# Episode: 442, Score: 500.0, Random: 22, Greedy: 336
# Episode: 443, Score: 500.0, Random: 20, Greedy: 347
# Episode: 444, Score: 500.0, Random: 17, Greedy: 360
# Episode: 445, Score: 500.0, Random: 20, Greedy: 366
# Episode: 446, Score: 500.0, Random: 21, Greedy: 365
# Episode: 447, Score: 500.0, Random: 20, Greedy: 362
# Episode: 448, Score: 500.0, Random: 19, Greedy: 361
# Episode: 449, Score: 500.0, Random: 13, Greedy: 361
# Episode: 450, Score: 500.0, Random: 16, Greedy: 363
# Episode: 451, Score: 500.0, Random: 16, Greedy: 366
# Episode: 452, Score: 500.0, Random: 17, Greedy: 359
# Episode: 453, Score: 500.0, Random: 16, Greedy: 358
# Episode: 454, Score: 500.0, Random: 20, Greedy: 351
# Episode: 455, Score: 500.0, Random: 25, Greedy: 359
# Episode: 456, Score: 500.0, Random: 19, Greedy: 350
# Episode: 457, Score: 77.0, Random: 6, Greedy: 56
# Episode: 458, Score: 500.0, Random: 17, Greedy: 366
# Episode: 459, Score: 500.0, Random: 20, Greedy: 348
# Episode: 460, Score: 500.0, Random: 24, Greedy: 355
# Episode: 461, Score: 500.0, Random: 19, Greedy: 356
# Episode: 462, Score: 500.0, Random: 16, Greedy: 364
# Episode: 463, Score: 500.0, Random: 11, Greedy: 354
# Episode: 464, Score: 500.0, Random: 21, Greedy: 359
# Episode: 465, Score: 500.0, Random: 14, Greedy: 357
# Episode: 466, Score: 500.0, Random: 22, Greedy: 355
# Episode: 467, Score: 500.0, Random: 15, Greedy: 357
# Episode: 468, Score: 500.0, Random: 18, Greedy: 372
# Episode: 469, Score: 500.0, Random: 22, Greedy: 360
# Episode: 470, Score: 500.0, Random: 28, Greedy: 351
# Episode: 471, Score: 500.0, Random: 23, Greedy: 353
# Episode: 472, Score: 500.0, Random: 24, Greedy: 353
# Episode: 473, Score: 500.0, Random: 15, Greedy: 357
# Episode: 474, Score: 500.0, Random: 20, Greedy: 349
# Episode: 475, Score: 500.0, Random: 22, Greedy: 351
# Episode: 476, Score: 500.0, Random: 10, Greedy: 349
# Episode: 477, Score: 500.0, Random: 25, Greedy: 366
# Episode: 478, Score: 500.0, Random: 16, Greedy: 350
# Episode: 479, Score: 500.0, Random: 16, Greedy: 361
# Episode: 480, Score: 500.0, Random: 25, Greedy: 362
# Episode: 481, Score: 500.0, Random: 31, Greedy: 348
# Episode: 482, Score: 500.0, Random: 17, Greedy: 356
# Episode: 483, Score: 500.0, Random: 13, Greedy: 361
# Episode: 484, Score: 500.0, Random: 21, Greedy: 333
# Episode: 485, Score: 500.0, Random: 17, Greedy: 350
# Episode: 486, Score: 500.0, Random: 21, Greedy: 355
# Episode: 487, Score: 500.0, Random: 17, Greedy: 360
# Episode: 488, Score: 500.0, Random: 15, Greedy: 348
# Episode: 489, Score: 500.0, Random: 16, Greedy: 367
# Episode: 490, Score: 500.0, Random: 18, Greedy: 348
# Episode: 491, Score: 500.0, Random: 21, Greedy: 358
# Episode: 492, Score: 500.0, Random: 25, Greedy: 349
# Episode: 493, Score: 500.0, Random: 15, Greedy: 357
# Episode: 494, Score: 108.0, Random: 6, Greedy: 73
# Episode: 495, Score: 500.0, Random: 13, Greedy: 367
# Episode: 496, Score: 500.0, Random: 24, Greedy: 356
# Episode: 497, Score: 500.0, Random: 18, Greedy: 344
# Episode: 498, Score: 500.0, Random: 21, Greedy: 356
# Episode: 499, Score: 500.0, Random: 15, Greedy: 352

# %%
rewards_test = []
for episode in range(10):
  obs1_val, info_val = env.reset()
  completed, term_val, trunc_val = False, False, False
  score, greedy_count, random_count = 0, 0, 0

  while not completed:
    action_val, action_type = policy_learnt(obs1_val)
    if action_type == 'greedy':
      greedy_count += 1
    else:
      random_count += 1
  
    obs2_val, reward_val, term_val, trunc_val, info_val = env.step(action_val)
    score += reward_val

    completed = term_val or trunc_val

    obs1_val = obs2_val

    if completed:
      print(f'Episode: {episode}, Score: {score}, Random: {random_count}, Greedy: {greedy_count}')
      rewards_test.append(score)
      break
# Out:
# Episode: 0, Score: 500.0, Random: 0, Greedy: 500
# Episode: 1, Score: 500.0, Random: 0, Greedy: 500
# Episode: 2, Score: 500.0, Random: 0, Greedy: 500
# Episode: 3, Score: 500.0, Random: 0, Greedy: 500
# Episode: 4, Score: 500.0, Random: 0, Greedy: 500
# Episode: 5, Score: 500.0, Random: 0, Greedy: 500
# Episode: 6, Score: 500.0, Random: 0, Greedy: 500
# Episode: 7, Score: 500.0, Random: 0, Greedy: 500
# Episode: 8, Score: 500.0, Random: 0, Greedy: 500
# Episode: 9, Score: 500.0, Random: 0, Greedy: 500

# %%
torch.save(nn_first.state_dict(), 'ddqn_modified_cartpole_weights.pth')

# %%
import matplotlib.pyplot as plt

def plot_reward(reward):
  plt.plot(reward, label='Reward')
  plt.xlabel('Episode')
  plt.ylabel('Reward Value')
  plt.title('Rewards Per Episode')
  plt.grid()
  plt.legend()
  plt.show()

plot_reward(rewards)
plot_reward(rewards_test)

# %%
import pickle
with open('ddqn_modified_cartpole_train.pkl', 'wb') as file:
  pickle.dump(rewards, file)

with open('ddqn_modified_cartpole_test.pkl', 'wb') as file:
  pickle.dump(rewards_test, file)
